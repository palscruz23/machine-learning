# %% [markdown]
# # # Remaining Useful Life Prediction with Informer on PHM08 Dataset

# %%
# %% [markdown]
# ## 1. Setup and Imports
import os
import urllib.request
import zipfile
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# from torchinfo import summary
import os 
import mlflow

# %%
# %% [markdown]
# Setup ML flow
mlflow.set_tracking_uri("file:///" + os.path.abspath("mlruns"))  # local ./mlruns folder
mlflow.set_experiment("predictive-rul-training")
# Out:
# 2025/08/26 15:22:23 INFO mlflow.tracking.fluent: Experiment with name 'predictive-rul-training' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:////mnt/custom-file-systems/efs/fs-090d41204a06429fd_fsap-0c5c0de8e6b7e5fbc/rul/machine-learning/supervised-learning/example/mlruns/366520510276751222', creation_time=1756221743544, experiment_id='366520510276751222', last_update_time=1756221743544, lifecycle_stage='active', name='predictive-rul-training', tags={}>

# %%
from typing import Dict, Any
import mlflow

def start_mlflow_run(params: Dict[str, Any]):
    """
    params: dict of hyperparameters and run context to record once per run.
    """
    run = mlflow.start_run()
    mlflow.set_tag("project", "RUL-estimation")
    mlflow.set_tag("author", "Pol John Cruz")
    mlflow.set_tag("dataset", "PHM08 Dataset")
    mlflow.log_params(params)
    return run

def log_epoch_metrics(epoch: int, train_loss: float, val_loss: float = None, extra: Dict[str, float] = None):
    mlflow.log_metric("train_loss", train_loss, step=epoch)
    if val_loss is not None:
        mlflow.log_metric("val_loss", val_loss, step=epoch)
    if extra:
        for k, v in extra.items():
            mlflow.log_metric(k, v, step=epoch)

# %%
# %% [markdown]
# ## 3. Load and Preprocess Data
def load_phm08(path, filename):
    cols = list(range(26))  # 26 columns
    df = pd.read_csv(os.path.join(path, filename), sep="\s+", header=None, names=cols)
    return df

train_df = load_phm08("data/Challenge_Data/", "train.txt")
test_df = load_phm08("data/Challenge_Data/", "test.txt")

# Extract RUL for training set
rul_per_unit = train_df.groupby(0)[1].max().reset_index()
rul_per_unit.columns = ["unit", "max_cycle"]
train_df = train_df.rename(columns={0: "unit", 1: "cycle"})
train_df = train_df.merge(rul_per_unit, on="unit", how="left")
train_df["RUL"] = train_df["max_cycle"] - train_df["cycle"]

# Extract RUL for training set
rul_per_unit_test = test_df.groupby(0)[1].max().reset_index()
rul_per_unit_test.columns = ["unit", "max_cycle"]
test_df = test_df.rename(columns={0: "unit", 1: "cycle"})
test_df = test_df.merge(rul_per_unit_test, on="unit", how="left")
test_df["RUL"] = test_df["max_cycle"] - test_df["cycle"]

# %%
train_df[train_df["unit"] == 2]
# Out:
#      unit  cycle        2       3      4       5       6        7        8  \
# 223     2      1   0.0017  0.0006  100.0  518.67  641.59  1578.61  1401.71
# 224     2      2  35.0026  0.8405   60.0  449.44  554.68  1357.66  1117.74
# 225     2      3  42.0011  0.8400   40.0  445.00  548.63  1347.31  1118.90
# 226     2      4  42.0003  0.8407   40.0  445.00  548.88  1350.73  1125.61
# 227     2      5  20.0023  0.7000    0.0  491.19  606.99  1477.32  1237.14
# ..    ...    ...      ...     ...    ...     ...     ...      ...      ...
# 382     2    160   0.0027  0.0000  100.0  518.67  643.58  1602.22  1431.34
# 383     2    161  42.0045  0.8418   40.0  445.00  550.82  1365.84  1144.76
# 384     2    162   0.0024  0.0000  100.0  518.67  643.87  1603.07  1429.17
# 385     2    163  35.0056  0.8417   60.0  449.44  556.59  1371.32  1153.13
# 386     2    164  25.0013  0.6200   80.0  462.54  537.29  1271.97  1066.91
#
#          9  ...       18       19    20   21    22      23     24       25  \
# 223  14.62  ...  8135.46   8.4292  0.03  392  2388  100.00  39.00  23.4589
# 224   5.48  ...  8066.59   9.2676  0.02  334  2223  100.00  14.69   8.9947
# 225   3.91  ...  8088.80   9.3370  0.02  330  2212  100.00  10.70   6.3830
# 226   3.91  ...  8086.30   9.3200  0.02  329  2212  100.00  10.43   6.3872
# 227   9.35  ...  8056.67   9.1704  0.02  364  2324  100.00  24.62  14.8277
# ..     ...  ...      ...      ...   ...  ...   ...     ...    ...      ...
# 382  14.62  ...  8123.17   8.5251  0.03  394  2388  100.00  38.54  23.1603
# 383   3.91  ...  8064.40   9.4743  0.02  334  2212  100.00  10.61   6.3184
# 384  14.62  ...  8119.39   8.5228  0.03  395  2388  100.00  38.51  23.1345
# 385   5.48  ...  8044.32   9.3913  0.02  337  2223  100.00  14.50   8.6654
# 386   7.05  ...  7861.65  11.0341  0.02  311  1915   84.93  14.16   8.3219
#
#      max_cycle  RUL
# 223        164  163
# 224        164  162
# 225        164  161
# 226        164  160
# 227        164  159
# ..         ...  ...
# 382        164    4
# 383        164    3
# 384        164    2
# 385        164    1
# 386        164    0
#
# [164 rows x 28 columns]

# %%
# %% [markdown]
# ## 4. Sliding Window Dataset
class PHM08RULDataset(Dataset):
    def __init__(self, df, seq_len=30, unit_ids=None):
        """
        df       : preprocessed dataframe with ['unit','cycle','RUL', features...]
        seq_len  : sequence length for time series
        unit_ids : list of engine IDs to include (if None → use all units)
        """
        if unit_ids is not None:
            self.df = df[df["unit"].isin(unit_ids)].reset_index(drop=True)
        else:
            self.df = df.copy().reset_index(drop=True)

        self.seq_len = seq_len

        # Features = all numeric columns except meta/labels
        self.features = self.df.columns.difference(
            ["unit", "cycle", "max_cycle", "RUL"]
        ).tolist()

        # Build all (X,y) sequences
        self.samples = []
        grouped = self.df.groupby("unit")
        for _, group in grouped:
            group = group.sort_values("cycle")
            values = group[self.features].values
            rul_values = group["RUL"].values

            for i in range(len(group) - seq_len + 1):
                x_seq = values[i:i+seq_len]
                y_val = rul_values[i+seq_len-1]
                self.samples.append((x_seq, y_val))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        x, y = self.samples[idx]
        return torch.tensor(x, dtype=torch.float32), torch.tensor(y, dtype=torch.float32)

seq_len = 100
units = train_df["unit"].unique()   # all engine IDs
print(f"Total engines: {len(units)}")
test_units = test_df["unit"].unique()   # all engine IDs
print(f"Total test engines: {len(units)}")

# First split into train+val vs test
train_units, val_units = train_test_split(units, test_size=0.2, random_state=42)

# Apply Feature scaling to transform the scaling of different features into similar scales.
feature_cols = train_df.columns.difference(["unit", "cycle", "max_cycle", "RUL"])
training_df = train_df[train_df["unit"].isin(train_units)].copy()
val_df   = train_df[train_df["unit"].isin(val_units)].copy()

scaler = StandardScaler()
training_df[feature_cols] = scaler.fit_transform(training_df[feature_cols])
val_df[feature_cols]   = scaler.transform(val_df[feature_cols])
test_df[feature_cols]  = scaler.transform(test_df[feature_cols])

from torch.utils.data import Subset

train_dataset = PHM08RULDataset(training_df, seq_len=seq_len, unit_ids=train_units)
val_dataset   = PHM08RULDataset(val_df, seq_len=seq_len, unit_ids=val_units)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=32, shuffle=False)
# Out:
# Total engines: 218
# Total test engines: 218

# %%
# %% [markdown]
# ----------------------
# Informer
# ----------------------
class ProbSparseSelfAttention(nn.Module):
    def __init__(self, d_model, n_heads):
        super().__init__()
        self.n_heads = n_heads
        self.d_k = d_model // n_heads

        self.q_linear = nn.Linear(d_model, d_model)
        self.k_linear = nn.Linear(d_model, d_model)
        self.v_linear = nn.Linear(d_model, d_model)
        self.fc_out = nn.Linear(d_model, d_model)

    def forward(self, x):
        B, L, D = x.shape
        H = self.n_heads

        Q = self.q_linear(x).view(B, L, H, self.d_k).transpose(1, 2)
        K = self.k_linear(x).view(B, L, H, self.d_k).transpose(1, 2)
        V = self.v_linear(x).view(B, L, H, self.d_k).transpose(1, 2)

        scores = torch.matmul(Q, K.transpose(-2, -1)) / (self.d_k ** 0.5)
        attn = torch.softmax(scores, dim=-1)
        out = torch.matmul(attn, V)
        out = out.transpose(1, 2).contiguous().view(B, L, D)
        return self.fc_out(out)


class EncoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff=256, dropout=0.1):
        super().__init__()
        self.attn = ProbSparseSelfAttention(d_model, n_heads)
        self.norm1 = nn.LayerNorm(d_model)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.ReLU(),
            nn.Linear(d_ff, d_model)
        )
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        attn_out = self.attn(x)
        x = self.norm1(x + self.dropout(attn_out))
        ff_out = self.ff(x)
        x = self.norm2(x + self.dropout(ff_out))
        return x


class InformerEncoder(nn.Module):
    def __init__(self, num_layers, d_model, n_heads):
        super().__init__()
        self.layers = nn.ModuleList([
            EncoderLayer(d_model, n_heads) for _ in range(num_layers)
        ])

    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x


class InformerRUL(nn.Module):
    def __init__(self, num_features, d_model=128, n_heads=4, num_layers=2):
        super().__init__()
        self.input_proj = nn.Linear(num_features, d_model)
        self.encoder = InformerEncoder(num_layers, d_model, n_heads)
        self.regressor = nn.Sequential(
            nn.AdaptiveAvgPool1d(1),
            nn.Flatten(),
            nn.Linear(d_model, 1)
        )

    def forward(self, x):
        x = self.input_proj(x)         # [B, L, d_model]
        x = self.encoder(x)            # [B, L, d_model]
        x = x.transpose(1, 2)          # [B, d_model, L]
        out = self.regressor(x)        # [B, 1]
        return out.squeeze(-1)

# %%
# ----------------------
# RNN Encoder-Decoder
# ----------------------
class RNNRUL(nn.Module):
    def __init__(self, input_dim, hidden_dim1=128, hidden_dim2=56, num_layers=2, dropout=0.3):
        super().__init__()
        self.rnn = nn.RNN(input_dim, hidden_dim1, num_layers, batch_first=True)
        self.bn = nn.BatchNorm1d(hidden_dim1)
        self.dropout1 = nn.Dropout(dropout)
        self.rnn2 = nn.RNN(hidden_dim1, hidden_dim2, num_layers, batch_first=True)
        self.dropout2 = nn.Dropout(dropout)
        self.relu = nn.ReLU()
        self.fc = nn.Linear(hidden_dim2, 1)

    def forward(self, x):
        out, _ = self.rnn(x)           # [B, L, H]
        out = out[:, -1, :]            # take last timestep
        out = self.bn(out)             # batch norm
        out = self.dropout1(out)       # first dropout

        out, _ = self.rnn2(out.unsqueeze(1))  # add 2nd RNN
        out = out[:, -1, :]

        out = self.dropout2(out)
        out = self.fc(out)
        return self.relu(out).squeeze(-1)

# ----------------------
# LSTM Encoder-Decoder
# ----------------------
class LSTMRUL(nn.Module):
    def __init__(self, input_dim, hidden_dim1=128, hidden_dim2=56, num_layers=2, dropout=0.3):
        super().__init__()
        self.lstm1 = nn.LSTM(input_dim, hidden_dim1, num_layers, batch_first=True)
        self.bn = nn.BatchNorm1d(hidden_dim1)
        self.dropout1 = nn.Dropout(dropout)
        self.lstm2 = nn.LSTM(hidden_dim1, hidden_dim2, num_layers, batch_first=True)
        self.dropout2 = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim2, 1)
        self.relu = nn.ReLU()

    def forward(self, x):
        out, _ = self.lstm1(x)
        out = out[:, -1, :]
        out = self.bn(out)
        out = self.dropout1(out)

        out, _ = self.lstm2(out.unsqueeze(1))
        out = out[:, -1, :]

        out = self.dropout2(out)
        out = self.fc(out)
        return self.relu(out).squeeze(-1)
# ----------------------
# Seq2Seq Encoder-Decoder
# ----------------------
class Seq2SeqRUL(nn.Module):
    def __init__(self, input_dim, hidden_dim1=128, hidden_dim2=56, num_layers=2, dropout=0.3):
        super().__init__()
        # Encoder
        self.encoder1 = nn.LSTM(input_dim, hidden_dim1, num_layers, batch_first=True)
        self.bn = nn.BatchNorm1d(hidden_dim1)
        self.dropout1 = nn.Dropout(dropout)

        # Second Encoder-like block
        self.encoder2 = nn.LSTM(hidden_dim1, hidden_dim2, num_layers, batch_first=True)
        self.dropout2 = nn.Dropout(dropout)

        self.relu = nn.ReLU()
        self.fc = nn.Linear(hidden_dim2, 1)


    def forward(self, x):
        enc_out, _ = self.encoder1(x)
        out = enc_out[:, -1, :]        # last timestep
        out = self.bn(out)
        out = self.dropout1(out)

        out, _ = self.encoder2(out.unsqueeze(1))
        out = out[:, -1, :]

        out = self.dropout2(out)
        out = self.fc(out)
        return self.relu(out).squeeze(-1)

# %%
# %% [markdown]
# ## 6. Training Function
import time

def train_model(model, train_loader, val_loader, opt="adam", device="cpu", epochs=20, lr=1e-3, mlflow=0):   
    model.to(device)
    criterion = nn.MSELoss()
    if opt == "adam":
        optimizer = optim.Adam(model.parameters(), lr=lr)
    elif opt == "rms":
        optimizer = optim.RMSprop(model.parameters(), lr=lr)
    train_losses = []
    val_losses = []
    for epoch in range(1, epochs+1):
        train_preds = []
        train_true_rul = []
        val_preds = []
        val_true_rul = []

        start = time.time()
        model.train()
        total_loss = 0
        for batch_idx, (x, y) in enumerate(train_loader, 1):
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            pred = model(x)
            loss = criterion(pred, y)
            train_preds.extend(pred.cpu().detach().numpy().ravel())
            train_true_rul.extend(y.cpu().detach().numpy().ravel())
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

            # # Print every 50 batches
            # if batch_idx % 50 == 0 or batch_idx == len(train_loader):
            #     print(f"Epoch {epoch}, Batch {batch_idx}/{len(train_loader)}, Batch Loss: {loss.item():.4f}")
        avg_train_loss = total_loss / len(train_loader)
        train_losses.append(avg_train_loss)
        val_loss = 0
        model.eval()
        with torch.no_grad():
            for x, y in val_loader:
                x, y = x.to(device), y.to(device)
                pred = model(x)
                val_preds.extend(pred.cpu().numpy().ravel())
                val_true_rul.extend(y.cpu().numpy().ravel())
                val_loss += criterion(pred, y).item()
        avg_val_loss = val_loss / len(val_loader)
        val_losses.append(avg_val_loss)
        end = time.time()
        total_time = end-start
        print(f"Epoch {epoch} Completed — Avg Train Loss: {avg_train_loss:.4f} | Avg Val Loss: {avg_val_loss:.4f} | Time Elapsed: {total_time:.2f} seconds")
        if mlflow==1:
            log_epoch_metrics(epoch, avg_train_loss, avg_val_loss)
    print("-"*60)

    return train_preds, train_true_rul, val_preds, val_true_rul, train_losses, val_losses

# %%
# Model selection
# Select models from RNN, LSTM, Informer ["RNN", "LSTM", "Seq2Seq", "Informer"]
num_features=len(train_dataset.features)

models = {
    "RNN": RNNRUL(num_features),
    "LSTM": LSTMRUL(num_features),
    "Seq2Seq": Seq2SeqRUL(num_features),
    "Informer": InformerRUL(num_features=len(train_dataset.features), d_model=128, n_heads=4, num_layers=2)   
}

# %%
from itertools import product

def grid_search(model_class, param_grid, train_dataset, val_dataset, device="cuda"):
    results = []
    best_model = None
    best_loss = float("inf")

    # Build train/val loaders
    for params in product(*param_grid.values()):
        hp = dict(zip(param_grid.keys(), params))

        # Sequencing
        seq_len = hp.get("seq_len",10)
        train_units, val_units = train_test_split(units, test_size=0.2, random_state=42)
        
        # Apply Feature scaling to transform the scaling of different features into similar scales.
        feature_cols = train_df.columns.difference(["unit", "cycle", "max_cycle", "RUL"])
        training_df = train_df[train_df["unit"].isin(train_units)].copy()
        val_df   = train_df[train_df["unit"].isin(val_units)].copy()
        
        scaler = StandardScaler()
        training_df[feature_cols] = scaler.fit_transform(training_df[feature_cols])
        val_df[feature_cols]   = scaler.transform(val_df[feature_cols])

        train_dataset = PHM08RULDataset(training_df, seq_len=seq_len, unit_ids=train_units)
        val_dataset   = PHM08RULDataset(val_df, seq_len=seq_len, unit_ids=val_units)

        # Dataloaders
        train_loader = DataLoader(train_dataset, batch_size=hp.get("batch_size",64), shuffle=True)
        val_loader   = DataLoader(val_dataset, batch_size=hp.get("batch_size",64))

        # Model
        if model_class.__name__ == "InformerRUL":
            model = model_class(
                num_features=len(train_dataset.features),
                d_model=hp.get("d_model", 128),
                n_heads=hp.get("n_heads", 4),
                num_layers=hp.get("num_layers", 2)
            )
            run_params = {
            "model": model_class.__name__,
            "dataset": "PHM08 Dataset",  
            # ---- hyperparams  ---- #
            "d_model": hp.get("d_model", 64),
            "n_heads": hp.get("n_heads", 1),
            "num_layers": hp.get("num_layers", 1),
            "batch_size": hp.get("batch_size",64),
            "seq_len": hp.get("seq_len",10),
            "lr": hp.get("lr", 1e-3),
            "epochs": hp.get("epochs", 20),
            "opt": hp.get("opt", "adam"),
            "device": device
            # -------------------- #
            }

        else:
            model = model_class(
                input_dim=len(train_dataset.features),
                hidden_dim1=hp.get("hidden_dim1", 128),
                hidden_dim2=hp.get("hidden_dim2", 128),
                num_layers=hp.get("num_layers", 1),
                dropout=hp.get("dropout", 0.1)
            )
            run_params = {
            "model": model_class.__name__,
            "dataset": "PHM08 Dataset",  
            # ---- hyperparams  ---- #
            "input_dim": num_features,
            "hidden_dim1": hp.get("hidden_dim1", 128),
            "hidden_dim2": hp.get("hidden_dim2", 128),
            "num_layers": hp.get("num_layers", 1),
            "dropout": hp.get("dropout", 0.1),
            "batch_size": hp.get("batch_size",64),
            "seq_len": hp.get("seq_len",10),
            "lr": hp.get("lr", 1e-3),
            "epochs": hp.get("epochs", 20),
            "opt": hp.get("opt", "adam"),
            "device": device
            # -------------------- #
            }


        #Initiate MLFlow run
        run = start_mlflow_run(run_params)
        start_time = time.time()

        
        print(f"\n🔎 Training with model {model.__class__.__name__} params: {hp}")
        train_preds, train_true_rul, val_preds, val_true_rul, train_loss, val_loss = train_model(
            model, train_loader, val_loader,
            epochs=hp.get("epochs", 20),
            lr=hp.get("lr", 1e-3),
            opt=hp.get("opt", "adam"),
            device=device,
            mlflow=1
        )
        train_secs = time.time() - start_time
        mlflow.log_metric("train_time_sec", train_secs)
        mlflow.end_run()
        results.append((hp, train_loss))

        if val_loss[-1] < best_loss:
            best_loss = val_loss[-1]
            best_model = model
            best_params = hp

    
    print("\n✅ Grid Search Complete")
    print(f"Best Params: {results[min(range(len(results)), key=lambda i: results[i][1])][0]}")
    print(f"Best Val Loss: {best_loss:.4f}")

    return best_model, best_params, best_loss, results

# %%
# Perform grid search with MLFlow

model_results = {}
model_names = ["RNN", "LSTM", "Seq2Seq", "Informer"]   # <-- change to "RNN", "LSTM", "Seq2Seq", "Informer"
device="cuda" if torch.cuda.is_available() else "cpu"

# Stops MLFlow instance if it exists
mlflow.end_run()

for model_name in model_names:
    model = models[model_name].to(device)
    if model_name == "Informer":
        param_grid = {
        "opt": ["rms", "adam"], 
        "seq_len": [50, 100],
        "batch_size": [32, 64],
        "lr": [1e-3, 1e-2],
        "d_model": [64, 128],
        "n_heads": [2, 4],
        "num_layers": [1, 2],
        "epochs": [10]  
        }
    else:
        param_grid = {
        "opt": ["rms", "adam"], 
        "hidden_dim1": [128],
        "hidden_dim2": [64],
        "num_layers": [1, 2],
        "dropout": [0.1],
        "seq_len": [50, 100],
        "batch_size": [32, 64],
        "lr": [1e-3, 1e-2],
        "epochs": [10]  
        }
    best_model, best_params, best_loss, results = grid_search(
        model.__class__, param_grid,
        train_dataset, val_dataset,
        device="cuda" if torch.cuda.is_available() else "cpu"
    )
    model_results[model.__class__.__name__] =  {
                                                    "Best Model": best_model,
                                                    "Best Params": best_params,
                                                    "Best Loss": best_loss,
                                                    "results": results
                                                }
# Out:
# 🔎 Training with model RNNRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 32, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 7847.6487 | Avg Val Loss: 7170.1678 | Time Elapsed: 3.01 seconds
# Epoch 2 Completed — Avg Train Loss: 6399.2230 | Avg Val Loss: 7223.3360 | Time Elapsed: 2.74 seconds
# Epoch 3 Completed — Avg Train Loss: 5243.8902 | Avg Val Loss: 4459.1149 | Time Elapsed: 2.82 seconds
# Epoch 4 Completed — Avg Train Loss: 3812.9941 | Avg Val Loss: 3302.1940 | Time Elapsed: 2.75 seconds
# Epoch 5 Completed — Avg Train Loss: 2286.6311 | Avg Val Loss: 2195.2897 | Time Elapsed: 2.78 seconds
# Epoch 6 Completed — Avg Train Loss: 1457.8251 | Avg Val Loss: 1260.5175 | Time Elapsed: 2.74 seconds
# Epoch 7 Completed — Avg Train Loss: 1357.1425 | Avg Val Loss: 2119.9966 | Time Elapsed: 2.73 seconds
# Epoch 8 Completed — Avg Train Loss: 1283.1181 | Avg Val Loss: 1710.0307 | Time Elapsed: 2.76 seconds
# Epoch 9 Completed — Avg Train Loss: 1274.8123 | Avg Val Loss: 1093.1641 | Time Elapsed: 2.77 seconds
# Epoch 10 Completed — Avg Train Loss: 1271.0861 | Avg Val Loss: 1199.4660 | Time Elapsed: 2.78 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 32, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 4233.6634 | Avg Val Loss: 3319.1607 | Time Elapsed: 2.76 seconds
# Epoch 2 Completed — Avg Train Loss: 3157.6820 | Avg Val Loss: 3308.0201 | Time Elapsed: 2.75 seconds
# Epoch 3 Completed — Avg Train Loss: 3153.3980 | Avg Val Loss: 3290.1588 | Time Elapsed: 2.77 seconds
# Epoch 4 Completed — Avg Train Loss: 3155.7386 | Avg Val Loss: 3292.2691 | Time Elapsed: 2.77 seconds
# Epoch 5 Completed — Avg Train Loss: 3153.7818 | Avg Val Loss: 3286.3782 | Time Elapsed: 2.74 seconds
# Epoch 6 Completed — Avg Train Loss: 3154.3717 | Avg Val Loss: 3311.7979 | Time Elapsed: 2.77 seconds
# Epoch 7 Completed — Avg Train Loss: 3152.1135 | Avg Val Loss: 3292.8546 | Time Elapsed: 2.73 seconds
# Epoch 8 Completed — Avg Train Loss: 3153.9717 | Avg Val Loss: 3299.5268 | Time Elapsed: 2.73 seconds
# Epoch 9 Completed — Avg Train Loss: 3151.8129 | Avg Val Loss: 3303.0280 | Time Elapsed: 2.74 seconds
# Epoch 10 Completed — Avg Train Loss: 3153.7257 | Avg Val Loss: 3298.4316 | Time Elapsed: 2.77 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 64, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 8941.9181 | Avg Val Loss: 8857.2608 | Time Elapsed: 1.65 seconds
# Epoch 2 Completed — Avg Train Loss: 7638.9093 | Avg Val Loss: 7711.1986 | Time Elapsed: 1.65 seconds
# Epoch 3 Completed — Avg Train Loss: 7084.4081 | Avg Val Loss: 7372.8648 | Time Elapsed: 1.65 seconds
# Epoch 4 Completed — Avg Train Loss: 6976.1728 | Avg Val Loss: 7325.3291 | Time Elapsed: 1.65 seconds
# Epoch 5 Completed — Avg Train Loss: 6950.1490 | Avg Val Loss: 7308.9278 | Time Elapsed: 1.64 seconds
# Epoch 6 Completed — Avg Train Loss: 6943.2696 | Avg Val Loss: 7496.9035 | Time Elapsed: 1.69 seconds
# Epoch 7 Completed — Avg Train Loss: 5732.4882 | Avg Val Loss: 3277.3711 | Time Elapsed: 1.67 seconds
# Epoch 8 Completed — Avg Train Loss: 3150.1945 | Avg Val Loss: 3287.2315 | Time Elapsed: 1.64 seconds
# Epoch 9 Completed — Avg Train Loss: 3133.5819 | Avg Val Loss: 3106.0696 | Time Elapsed: 1.63 seconds
# Epoch 10 Completed — Avg Train Loss: 1900.9667 | Avg Val Loss: 1484.0423 | Time Elapsed: 1.67 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 64, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 3344.3007 | Avg Val Loss: 3279.2730 | Time Elapsed: 1.64 seconds
# Epoch 2 Completed — Avg Train Loss: 3152.3177 | Avg Val Loss: 3303.4978 | Time Elapsed: 1.64 seconds
# Epoch 3 Completed — Avg Train Loss: 3149.5839 | Avg Val Loss: 3278.6771 | Time Elapsed: 1.65 seconds
# Epoch 4 Completed — Avg Train Loss: 3148.5867 | Avg Val Loss: 3297.1349 | Time Elapsed: 1.64 seconds
# Epoch 5 Completed — Avg Train Loss: 3152.1634 | Avg Val Loss: 3292.1100 | Time Elapsed: 1.62 seconds
# Epoch 6 Completed — Avg Train Loss: 3152.0359 | Avg Val Loss: 3311.3448 | Time Elapsed: 1.64 seconds
# Epoch 7 Completed — Avg Train Loss: 3153.8852 | Avg Val Loss: 3302.3490 | Time Elapsed: 1.66 seconds
# Epoch 8 Completed — Avg Train Loss: 3154.7121 | Avg Val Loss: 3292.6838 | Time Elapsed: 1.66 seconds
# Epoch 9 Completed — Avg Train Loss: 3148.0496 | Avg Val Loss: 3287.1365 | Time Elapsed: 1.63 seconds
# Epoch 10 Completed — Avg Train Loss: 3151.9541 | Avg Val Loss: 3293.8006 | Time Elapsed: 1.65 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 32, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 4998.9483 | Avg Val Loss: 4940.6249 | Time Elapsed: 1.98 seconds
# Epoch 2 Completed — Avg Train Loss: 4523.3521 | Avg Val Loss: 4737.8059 | Time Elapsed: 1.96 seconds
# Epoch 3 Completed — Avg Train Loss: 4483.4746 | Avg Val Loss: 4735.8788 | Time Elapsed: 2.02 seconds
# Epoch 4 Completed — Avg Train Loss: 4401.2212 | Avg Val Loss: 4182.4066 | Time Elapsed: 1.97 seconds
# Epoch 5 Completed — Avg Train Loss: 3908.6792 | Avg Val Loss: 4108.0413 | Time Elapsed: 1.96 seconds
# Epoch 6 Completed — Avg Train Loss: 3743.9916 | Avg Val Loss: 3900.3756 | Time Elapsed: 1.99 seconds
# Epoch 7 Completed — Avg Train Loss: 3007.8815 | Avg Val Loss: 1541.5836 | Time Elapsed: 1.95 seconds
# Epoch 8 Completed — Avg Train Loss: 1490.9455 | Avg Val Loss: 3104.2571 | Time Elapsed: 1.96 seconds
# Epoch 9 Completed — Avg Train Loss: 934.7309 | Avg Val Loss: 1145.9504 | Time Elapsed: 1.95 seconds
# Epoch 10 Completed — Avg Train Loss: 772.1157 | Avg Val Loss: 5237.0957 | Time Elapsed: 1.96 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 32, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 2083.5229 | Avg Val Loss: 2085.6168 | Time Elapsed: 1.97 seconds
# Epoch 2 Completed — Avg Train Loss: 2032.0831 | Avg Val Loss: 2072.1559 | Time Elapsed: 1.98 seconds
# Epoch 3 Completed — Avg Train Loss: 2035.7711 | Avg Val Loss: 2058.2948 | Time Elapsed: 1.99 seconds
# Epoch 4 Completed — Avg Train Loss: 2041.5641 | Avg Val Loss: 2061.7703 | Time Elapsed: 1.97 seconds
# Epoch 5 Completed — Avg Train Loss: 2045.6736 | Avg Val Loss: 2067.3581 | Time Elapsed: 1.98 seconds
# Epoch 6 Completed — Avg Train Loss: 2057.0277 | Avg Val Loss: 2077.8359 | Time Elapsed: 1.96 seconds
# Epoch 7 Completed — Avg Train Loss: 2044.3128 | Avg Val Loss: 2094.8489 | Time Elapsed: 2.00 seconds
# Epoch 8 Completed — Avg Train Loss: 2064.6950 | Avg Val Loss: 2094.1024 | Time Elapsed: 2.01 seconds
# Epoch 9 Completed — Avg Train Loss: 2067.7356 | Avg Val Loss: 2062.6109 | Time Elapsed: 1.96 seconds
# Epoch 10 Completed — Avg Train Loss: 2067.0477 | Avg Val Loss: 2066.9013 | Time Elapsed: 1.97 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 64, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 4341.1930 | Avg Val Loss: 3949.4821 | Time Elapsed: 1.21 seconds
# Epoch 2 Completed — Avg Train Loss: 3330.8774 | Avg Val Loss: 3208.5934 | Time Elapsed: 1.19 seconds
# Epoch 3 Completed — Avg Train Loss: 2684.5343 | Avg Val Loss: 2449.1793 | Time Elapsed: 1.20 seconds
# Epoch 4 Completed — Avg Train Loss: 1977.6146 | Avg Val Loss: 1524.2839 | Time Elapsed: 1.19 seconds
# Epoch 5 Completed — Avg Train Loss: 1110.2921 | Avg Val Loss: 1469.5937 | Time Elapsed: 1.20 seconds
# Epoch 6 Completed — Avg Train Loss: 844.4051 | Avg Val Loss: 774.9546 | Time Elapsed: 1.20 seconds
# Epoch 7 Completed — Avg Train Loss: 771.3959 | Avg Val Loss: 2774.7823 | Time Elapsed: 1.21 seconds
# Epoch 8 Completed — Avg Train Loss: 742.6556 | Avg Val Loss: 3955.9037 | Time Elapsed: 1.20 seconds
# Epoch 9 Completed — Avg Train Loss: 733.5193 | Avg Val Loss: 1303.2889 | Time Elapsed: 1.19 seconds
# Epoch 10 Completed — Avg Train Loss: 716.6299 | Avg Val Loss: 4622.9877 | Time Elapsed: 1.22 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 64, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 2126.7181 | Avg Val Loss: 2071.9196 | Time Elapsed: 1.24 seconds
# Epoch 2 Completed — Avg Train Loss: 2021.8788 | Avg Val Loss: 2062.2146 | Time Elapsed: 1.20 seconds
# Epoch 3 Completed — Avg Train Loss: 2021.2839 | Avg Val Loss: 2068.6585 | Time Elapsed: 1.20 seconds
# Epoch 4 Completed — Avg Train Loss: 2024.0983 | Avg Val Loss: 2095.1386 | Time Elapsed: 1.20 seconds
# Epoch 5 Completed — Avg Train Loss: 2021.7306 | Avg Val Loss: 2068.8843 | Time Elapsed: 1.20 seconds
# Epoch 6 Completed — Avg Train Loss: 2019.5445 | Avg Val Loss: 2068.2473 | Time Elapsed: 1.20 seconds
# Epoch 7 Completed — Avg Train Loss: 2018.5224 | Avg Val Loss: 2062.4573 | Time Elapsed: 1.19 seconds
# Epoch 8 Completed — Avg Train Loss: 2020.0354 | Avg Val Loss: 2066.8137 | Time Elapsed: 1.21 seconds
# Epoch 9 Completed — Avg Train Loss: 2026.6301 | Avg Val Loss: 2071.9672 | Time Elapsed: 1.23 seconds
# Epoch 10 Completed — Avg Train Loss: 2024.5460 | Avg Val Loss: 2072.6996 | Time Elapsed: 1.23 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 2, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 32, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 5579.8476 | Avg Val Loss: 3865.8552 | Time Elapsed: 3.08 seconds
# Epoch 2 Completed — Avg Train Loss: 3248.5788 | Avg Val Loss: 3291.8925 | Time Elapsed: 3.10 seconds
# Epoch 3 Completed — Avg Train Loss: 3148.6126 | Avg Val Loss: 3294.4030 | Time Elapsed: 3.08 seconds
# Epoch 4 Completed — Avg Train Loss: 3142.5231 | Avg Val Loss: 3296.3414 | Time Elapsed: 3.07 seconds
# Epoch 5 Completed — Avg Train Loss: 3153.0808 | Avg Val Loss: 3292.3878 | Time Elapsed: 3.09 seconds
# Epoch 6 Completed — Avg Train Loss: 3147.1032 | Avg Val Loss: 3291.5330 | Time Elapsed: 3.11 seconds
# Epoch 7 Completed — Avg Train Loss: 3146.4646 | Avg Val Loss: 3295.4579 | Time Elapsed: 3.08 seconds
# Epoch 8 Completed — Avg Train Loss: 3152.0338 | Avg Val Loss: 3295.4287 | Time Elapsed: 3.08 seconds
# Epoch 9 Completed — Avg Train Loss: 3150.7439 | Avg Val Loss: 3293.1222 | Time Elapsed: 3.13 seconds
# Epoch 10 Completed — Avg Train Loss: 3148.3765 | Avg Val Loss: 3291.5278 | Time Elapsed: 3.10 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 2, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 32, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 5359.2363 | Avg Val Loss: 5763.7206 | Time Elapsed: 3.11 seconds
# Epoch 2 Completed — Avg Train Loss: 5320.5372 | Avg Val Loss: 5789.6494 | Time Elapsed: 3.09 seconds
# Epoch 3 Completed — Avg Train Loss: 5338.0310 | Avg Val Loss: 5789.6528 | Time Elapsed: 3.07 seconds
# Epoch 4 Completed — Avg Train Loss: 5129.2723 | Avg Val Loss: 5440.1882 | Time Elapsed: 3.10 seconds
# Epoch 5 Completed — Avg Train Loss: 5023.7750 | Avg Val Loss: 5435.8453 | Time Elapsed: 3.11 seconds
# Epoch 6 Completed — Avg Train Loss: 4512.3004 | Avg Val Loss: 3281.6744 | Time Elapsed: 3.09 seconds
# Epoch 7 Completed — Avg Train Loss: 3152.9900 | Avg Val Loss: 3287.6198 | Time Elapsed: 3.10 seconds
# Epoch 8 Completed — Avg Train Loss: 3150.3800 | Avg Val Loss: 3287.4668 | Time Elapsed: 3.08 seconds
# Epoch 9 Completed — Avg Train Loss: 3145.6740 | Avg Val Loss: 3288.8428 | Time Elapsed: 3.13 seconds
# Epoch 10 Completed — Avg Train Loss: 3153.2863 | Avg Val Loss: 3295.3676 | Time Elapsed: 3.06 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 2, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 64, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 7946.3755 | Avg Val Loss: 7456.2880 | Time Elapsed: 1.83 seconds
# Epoch 2 Completed — Avg Train Loss: 6204.5162 | Avg Val Loss: 6211.1650 | Time Elapsed: 1.81 seconds
# Epoch 3 Completed — Avg Train Loss: 5449.0855 | Avg Val Loss: 5782.2940 | Time Elapsed: 1.80 seconds
# Epoch 4 Completed — Avg Train Loss: 5295.9919 | Avg Val Loss: 5741.7998 | Time Elapsed: 1.81 seconds
# Epoch 5 Completed — Avg Train Loss: 5093.0791 | Avg Val Loss: 5387.5527 | Time Elapsed: 1.80 seconds
# Epoch 6 Completed — Avg Train Loss: 5047.0254 | Avg Val Loss: 5344.2848 | Time Elapsed: 1.81 seconds
# Epoch 7 Completed — Avg Train Loss: 4985.5998 | Avg Val Loss: 5345.2221 | Time Elapsed: 1.83 seconds
# Epoch 8 Completed — Avg Train Loss: 4998.4224 | Avg Val Loss: 5346.8851 | Time Elapsed: 1.85 seconds
# Epoch 9 Completed — Avg Train Loss: 4695.7165 | Avg Val Loss: 3140.3652 | Time Elapsed: 1.80 seconds
# Epoch 10 Completed — Avg Train Loss: 1853.8430 | Avg Val Loss: 3799.4923 | Time Elapsed: 1.82 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 2, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 64, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 3351.3751 | Avg Val Loss: 3280.4430 | Time Elapsed: 1.80 seconds
# Epoch 2 Completed — Avg Train Loss: 3147.3847 | Avg Val Loss: 3307.2423 | Time Elapsed: 1.82 seconds
# Epoch 3 Completed — Avg Train Loss: 3149.3073 | Avg Val Loss: 3299.4273 | Time Elapsed: 1.87 seconds
# Epoch 4 Completed — Avg Train Loss: 3150.7991 | Avg Val Loss: 3280.4057 | Time Elapsed: 1.83 seconds
# Epoch 5 Completed — Avg Train Loss: 3150.9811 | Avg Val Loss: 3278.9669 | Time Elapsed: 1.80 seconds
# Epoch 6 Completed — Avg Train Loss: 3152.9136 | Avg Val Loss: 3280.3288 | Time Elapsed: 1.81 seconds
# Epoch 7 Completed — Avg Train Loss: 3152.4034 | Avg Val Loss: 3292.2234 | Time Elapsed: 1.81 seconds
# Epoch 8 Completed — Avg Train Loss: 3146.9797 | Avg Val Loss: 3300.7164 | Time Elapsed: 1.83 seconds
# Epoch 9 Completed — Avg Train Loss: 3149.3105 | Avg Val Loss: 3292.4342 | Time Elapsed: 1.81 seconds
# Epoch 10 Completed — Avg Train Loss: 3149.2543 | Avg Val Loss: 3299.3391 | Time Elapsed: 1.80 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 2, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 32, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 3292.2423 | Avg Val Loss: 2428.6711 | Time Elapsed: 2.18 seconds
# Epoch 2 Completed — Avg Train Loss: 2091.0982 | Avg Val Loss: 2070.9110 | Time Elapsed: 2.20 seconds
# Epoch 3 Completed — Avg Train Loss: 2021.8897 | Avg Val Loss: 2066.2044 | Time Elapsed: 2.23 seconds
# Epoch 4 Completed — Avg Train Loss: 2022.9776 | Avg Val Loss: 2065.1480 | Time Elapsed: 2.19 seconds
# Epoch 5 Completed — Avg Train Loss: 2019.8415 | Avg Val Loss: 2065.1882 | Time Elapsed: 2.19 seconds
# Epoch 6 Completed — Avg Train Loss: 2021.1021 | Avg Val Loss: 2064.6283 | Time Elapsed: 2.18 seconds
# Epoch 7 Completed — Avg Train Loss: 2021.3669 | Avg Val Loss: 2061.6026 | Time Elapsed: 2.21 seconds
# Epoch 8 Completed — Avg Train Loss: 2018.8748 | Avg Val Loss: 2060.8777 | Time Elapsed: 2.23 seconds
# Epoch 9 Completed — Avg Train Loss: 2020.8656 | Avg Val Loss: 2062.0731 | Time Elapsed: 2.18 seconds
# Epoch 10 Completed — Avg Train Loss: 2021.7361 | Avg Val Loss: 2062.8687 | Time Elapsed: 2.21 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 2, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 32, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 2079.4862 | Avg Val Loss: 2058.5871 | Time Elapsed: 2.18 seconds
# Epoch 2 Completed — Avg Train Loss: 2022.8979 | Avg Val Loss: 2062.0012 | Time Elapsed: 2.19 seconds
# Epoch 3 Completed — Avg Train Loss: 2026.0034 | Avg Val Loss: 2067.6398 | Time Elapsed: 2.19 seconds
# Epoch 4 Completed — Avg Train Loss: 4136.2026 | Avg Val Loss: 4393.8989 | Time Elapsed: 2.19 seconds
# Epoch 5 Completed — Avg Train Loss: 4242.7175 | Avg Val Loss: 4387.8687 | Time Elapsed: 2.21 seconds
# Epoch 6 Completed — Avg Train Loss: 2130.8257 | Avg Val Loss: 2085.2115 | Time Elapsed: 2.23 seconds
# Epoch 7 Completed — Avg Train Loss: 2025.2599 | Avg Val Loss: 2087.5690 | Time Elapsed: 2.18 seconds
# Epoch 8 Completed — Avg Train Loss: 2020.3560 | Avg Val Loss: 2057.3852 | Time Elapsed: 2.21 seconds
# Epoch 9 Completed — Avg Train Loss: 2025.0924 | Avg Val Loss: 2062.9436 | Time Elapsed: 2.18 seconds
# Epoch 10 Completed — Avg Train Loss: 2034.0981 | Avg Val Loss: 2056.8512 | Time Elapsed: 2.21 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 2, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 64, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 4402.7844 | Avg Val Loss: 4124.5418 | Time Elapsed: 1.36 seconds
# Epoch 2 Completed — Avg Train Loss: 3449.8431 | Avg Val Loss: 3462.8944 | Time Elapsed: 1.33 seconds
# Epoch 3 Completed — Avg Train Loss: 3046.0802 | Avg Val Loss: 3202.1824 | Time Elapsed: 1.30 seconds
# Epoch 4 Completed — Avg Train Loss: 2943.9891 | Avg Val Loss: 3159.0816 | Time Elapsed: 1.32 seconds
# Epoch 5 Completed — Avg Train Loss: 2936.9126 | Avg Val Loss: 3156.9095 | Time Elapsed: 1.34 seconds
# Epoch 6 Completed — Avg Train Loss: 2935.9160 | Avg Val Loss: 3155.8823 | Time Elapsed: 1.30 seconds
# Epoch 7 Completed — Avg Train Loss: 2928.6252 | Avg Val Loss: 3157.8366 | Time Elapsed: 1.32 seconds
# Epoch 8 Completed — Avg Train Loss: 2811.7691 | Avg Val Loss: 2916.5717 | Time Elapsed: 1.31 seconds
# Epoch 9 Completed — Avg Train Loss: 2716.5033 | Avg Val Loss: 2915.7621 | Time Elapsed: 1.31 seconds
# Epoch 10 Completed — Avg Train Loss: 2711.5063 | Avg Val Loss: 2918.8009 | Time Elapsed: 1.32 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 2, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 64, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 2141.4205 | Avg Val Loss: 2077.2756 | Time Elapsed: 1.31 seconds
# Epoch 2 Completed — Avg Train Loss: 2019.6651 | Avg Val Loss: 2061.7692 | Time Elapsed: 1.32 seconds
# Epoch 3 Completed — Avg Train Loss: 2019.5917 | Avg Val Loss: 2066.2397 | Time Elapsed: 1.33 seconds
# Epoch 4 Completed — Avg Train Loss: 2023.2447 | Avg Val Loss: 2073.0960 | Time Elapsed: 1.34 seconds
# Epoch 5 Completed — Avg Train Loss: 2022.7346 | Avg Val Loss: 2072.9879 | Time Elapsed: 1.34 seconds
# Epoch 6 Completed — Avg Train Loss: 2021.6525 | Avg Val Loss: 2072.4501 | Time Elapsed: 1.32 seconds
# Epoch 7 Completed — Avg Train Loss: 2022.2380 | Avg Val Loss: 2071.7795 | Time Elapsed: 1.32 seconds
# Epoch 8 Completed — Avg Train Loss: 2019.7277 | Avg Val Loss: 2071.2237 | Time Elapsed: 1.32 seconds
# Epoch 9 Completed — Avg Train Loss: 2018.0638 | Avg Val Loss: 2062.4283 | Time Elapsed: 1.31 seconds
# Epoch 10 Completed — Avg Train Loss: 2026.1125 | Avg Val Loss: 2082.0520 | Time Elapsed: 1.31 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'adam', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 32, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 6880.0136 | Avg Val Loss: 5124.4485 | Time Elapsed: 2.89 seconds
# Epoch 2 Completed — Avg Train Loss: 4264.2709 | Avg Val Loss: 4164.2736 | Time Elapsed: 2.81 seconds
# Epoch 3 Completed — Avg Train Loss: 3987.4278 | Avg Val Loss: 4109.1656 | Time Elapsed: 2.83 seconds
# Epoch 4 Completed — Avg Train Loss: 2800.1878 | Avg Val Loss: 2131.1221 | Time Elapsed: 2.79 seconds
# Epoch 5 Completed — Avg Train Loss: 1675.1573 | Avg Val Loss: 2145.4873 | Time Elapsed: 2.79 seconds
# Epoch 6 Completed — Avg Train Loss: 1529.6930 | Avg Val Loss: 1664.2393 | Time Elapsed: 2.81 seconds
# Epoch 7 Completed — Avg Train Loss: 1512.3364 | Avg Val Loss: 3999.1931 | Time Elapsed: 2.83 seconds
# Epoch 8 Completed — Avg Train Loss: 1344.5091 | Avg Val Loss: 1446.1623 | Time Elapsed: 2.85 seconds
# Epoch 9 Completed — Avg Train Loss: 1232.5781 | Avg Val Loss: 5372.9184 | Time Elapsed: 2.82 seconds
# Epoch 10 Completed — Avg Train Loss: 1226.1109 | Avg Val Loss: 9396.6003 | Time Elapsed: 2.81 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'adam', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 32, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 3517.7367 | Avg Val Loss: 3318.2735 | Time Elapsed: 2.86 seconds
# Epoch 2 Completed — Avg Train Loss: 3146.6525 | Avg Val Loss: 3315.5240 | Time Elapsed: 2.85 seconds
# Epoch 3 Completed — Avg Train Loss: 3150.7913 | Avg Val Loss: 3288.7866 | Time Elapsed: 2.82 seconds
# Epoch 4 Completed — Avg Train Loss: 3148.3447 | Avg Val Loss: 3296.0923 | Time Elapsed: 2.83 seconds
# Epoch 5 Completed — Avg Train Loss: 3150.2686 | Avg Val Loss: 3294.3853 | Time Elapsed: 2.81 seconds
# Epoch 6 Completed — Avg Train Loss: 3155.1674 | Avg Val Loss: 3282.8060 | Time Elapsed: 2.83 seconds
# Epoch 7 Completed — Avg Train Loss: 3153.9631 | Avg Val Loss: 3281.2475 | Time Elapsed: 2.82 seconds
# Epoch 8 Completed — Avg Train Loss: 3152.8067 | Avg Val Loss: 3292.0678 | Time Elapsed: 2.86 seconds
# Epoch 9 Completed — Avg Train Loss: 3152.1343 | Avg Val Loss: 3295.5373 | Time Elapsed: 2.83 seconds
# Epoch 10 Completed — Avg Train Loss: 3146.4374 | Avg Val Loss: 3281.7931 | Time Elapsed: 2.84 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'adam', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 64, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 8089.6077 | Avg Val Loss: 6969.8879 | Time Elapsed: 1.68 seconds
# Epoch 2 Completed — Avg Train Loss: 5615.7269 | Avg Val Loss: 5390.7966 | Time Elapsed: 1.72 seconds
# Epoch 3 Completed — Avg Train Loss: 4202.0142 | Avg Val Loss: 4649.2993 | Time Elapsed: 1.71 seconds
# Epoch 4 Completed — Avg Train Loss: 3128.6058 | Avg Val Loss: 2602.5088 | Time Elapsed: 1.67 seconds
# Epoch 5 Completed — Avg Train Loss: 2030.4160 | Avg Val Loss: 2461.4934 | Time Elapsed: 1.68 seconds
# Epoch 6 Completed — Avg Train Loss: 1594.0467 | Avg Val Loss: 1495.8361 | Time Elapsed: 1.70 seconds
# Epoch 7 Completed — Avg Train Loss: 1346.1121 | Avg Val Loss: 1243.3012 | Time Elapsed: 1.66 seconds
# Epoch 8 Completed — Avg Train Loss: 1282.7201 | Avg Val Loss: 2168.5456 | Time Elapsed: 1.67 seconds
# Epoch 9 Completed — Avg Train Loss: 1241.5794 | Avg Val Loss: 4682.8222 | Time Elapsed: 1.67 seconds
# Epoch 10 Completed — Avg Train Loss: 2024.5399 | Avg Val Loss: 2717.4138 | Time Elapsed: 1.68 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'adam', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 64, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 4868.6542 | Avg Val Loss: 4461.3368 | Time Elapsed: 1.69 seconds
# Epoch 2 Completed — Avg Train Loss: 4263.7604 | Avg Val Loss: 4448.5936 | Time Elapsed: 1.71 seconds
# Epoch 3 Completed — Avg Train Loss: 4268.7593 | Avg Val Loss: 4450.2384 | Time Elapsed: 1.71 seconds
# Epoch 4 Completed — Avg Train Loss: 4268.0516 | Avg Val Loss: 4449.2637 | Time Elapsed: 1.71 seconds
# Epoch 5 Completed — Avg Train Loss: 4264.2005 | Avg Val Loss: 4463.1388 | Time Elapsed: 1.70 seconds
# Epoch 6 Completed — Avg Train Loss: 4267.0489 | Avg Val Loss: 4456.9927 | Time Elapsed: 1.70 seconds
# Epoch 7 Completed — Avg Train Loss: 4266.1922 | Avg Val Loss: 4458.7605 | Time Elapsed: 1.68 seconds
# Epoch 8 Completed — Avg Train Loss: 4266.9121 | Avg Val Loss: 4464.3845 | Time Elapsed: 1.68 seconds
# Epoch 9 Completed — Avg Train Loss: 4268.2225 | Avg Val Loss: 4453.4188 | Time Elapsed: 1.73 seconds
# Epoch 10 Completed — Avg Train Loss: 4269.0547 | Avg Val Loss: 4460.6768 | Time Elapsed: 1.72 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'adam', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 32, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 4682.1139 | Avg Val Loss: 4197.7831 | Time Elapsed: 2.01 seconds
# Epoch 2 Completed — Avg Train Loss: 3727.1623 | Avg Val Loss: 3703.6115 | Time Elapsed: 2.03 seconds
# Epoch 3 Completed — Avg Train Loss: 3561.0152 | Avg Val Loss: 3620.5152 | Time Elapsed: 1.99 seconds
# Epoch 4 Completed — Avg Train Loss: 3548.6438 | Avg Val Loss: 3630.3553 | Time Elapsed: 1.99 seconds
# Epoch 5 Completed — Avg Train Loss: 3560.1974 | Avg Val Loss: 3626.5043 | Time Elapsed: 2.00 seconds
# Epoch 6 Completed — Avg Train Loss: 3560.4517 | Avg Val Loss: 3653.9599 | Time Elapsed: 2.03 seconds
# Epoch 7 Completed — Avg Train Loss: 3581.7417 | Avg Val Loss: 3657.9070 | Time Elapsed: 2.02 seconds
# Epoch 8 Completed — Avg Train Loss: 3594.8713 | Avg Val Loss: 3694.9126 | Time Elapsed: 2.02 seconds
# Epoch 9 Completed — Avg Train Loss: 3597.8498 | Avg Val Loss: 3665.3314 | Time Elapsed: 2.04 seconds
# Epoch 10 Completed — Avg Train Loss: 3460.0104 | Avg Val Loss: 2542.4531 | Time Elapsed: 2.01 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'adam', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 32, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 3879.1041 | Avg Val Loss: 4033.3528 | Time Elapsed: 2.04 seconds
# Epoch 2 Completed — Avg Train Loss: 3744.7606 | Avg Val Loss: 4035.5340 | Time Elapsed: 2.01 seconds
# Epoch 3 Completed — Avg Train Loss: 3744.3547 | Avg Val Loss: 4036.1805 | Time Elapsed: 2.05 seconds
# Epoch 4 Completed — Avg Train Loss: 3744.0473 | Avg Val Loss: 4038.4015 | Time Elapsed: 2.07 seconds
# Epoch 5 Completed — Avg Train Loss: 3745.3218 | Avg Val Loss: 4038.9800 | Time Elapsed: 2.01 seconds
# Epoch 6 Completed — Avg Train Loss: 3745.0755 | Avg Val Loss: 4031.7898 | Time Elapsed: 2.02 seconds
# Epoch 7 Completed — Avg Train Loss: 3738.6510 | Avg Val Loss: 4030.9418 | Time Elapsed: 2.04 seconds
# Epoch 8 Completed — Avg Train Loss: 3739.6635 | Avg Val Loss: 4028.4901 | Time Elapsed: 2.01 seconds
# Epoch 9 Completed — Avg Train Loss: 3740.2760 | Avg Val Loss: 4035.6717 | Time Elapsed: 2.00 seconds
# Epoch 10 Completed — Avg Train Loss: 3740.9348 | Avg Val Loss: 4042.6575 | Time Elapsed: 2.00 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'adam', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 64, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 4896.8296 | Avg Val Loss: 4545.4407 | Time Elapsed: 1.22 seconds
# Epoch 2 Completed — Avg Train Loss: 3719.1367 | Avg Val Loss: 3329.7682 | Time Elapsed: 1.23 seconds
# Epoch 3 Completed — Avg Train Loss: 2845.9783 | Avg Val Loss: 6411.7207 | Time Elapsed: 1.25 seconds
# Epoch 4 Completed — Avg Train Loss: 2244.8436 | Avg Val Loss: 3061.0148 | Time Elapsed: 1.25 seconds
# Epoch 5 Completed — Avg Train Loss: 1913.3884 | Avg Val Loss: 2169.5960 | Time Elapsed: 1.24 seconds
# Epoch 6 Completed — Avg Train Loss: 1741.0372 | Avg Val Loss: 2878.6663 | Time Elapsed: 1.23 seconds
# Epoch 7 Completed — Avg Train Loss: 1642.6195 | Avg Val Loss: 5342.0063 | Time Elapsed: 1.24 seconds
# Epoch 8 Completed — Avg Train Loss: 944.2445 | Avg Val Loss: 1137.9881 | Time Elapsed: 1.24 seconds
# Epoch 9 Completed — Avg Train Loss: 778.4248 | Avg Val Loss: 1562.1320 | Time Elapsed: 1.23 seconds
# Epoch 10 Completed — Avg Train Loss: 753.7193 | Avg Val Loss: 6114.0061 | Time Elapsed: 1.23 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'adam', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 64, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 2540.4226 | Avg Val Loss: 2071.6186 | Time Elapsed: 1.27 seconds
# Epoch 2 Completed — Avg Train Loss: 2020.6752 | Avg Val Loss: 2072.4789 | Time Elapsed: 1.27 seconds
# Epoch 3 Completed — Avg Train Loss: 2020.8897 | Avg Val Loss: 2078.8873 | Time Elapsed: 1.25 seconds
# Epoch 4 Completed — Avg Train Loss: 2019.8784 | Avg Val Loss: 2075.0757 | Time Elapsed: 1.22 seconds
# Epoch 5 Completed — Avg Train Loss: 2020.9406 | Avg Val Loss: 2077.1374 | Time Elapsed: 1.22 seconds
# Epoch 6 Completed — Avg Train Loss: 2021.7241 | Avg Val Loss: 2064.2825 | Time Elapsed: 1.24 seconds
# Epoch 7 Completed — Avg Train Loss: 2020.8079 | Avg Val Loss: 2063.9920 | Time Elapsed: 1.27 seconds
# Epoch 8 Completed — Avg Train Loss: 2020.9291 | Avg Val Loss: 2072.1992 | Time Elapsed: 1.22 seconds
# Epoch 9 Completed — Avg Train Loss: 2019.2443 | Avg Val Loss: 2064.5585 | Time Elapsed: 1.23 seconds
# Epoch 10 Completed — Avg Train Loss: 2020.4461 | Avg Val Loss: 2067.2320 | Time Elapsed: 1.22 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'adam', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 2, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 32, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 7271.4142 | Avg Val Loss: 6100.7306 | Time Elapsed: 3.17 seconds
# Epoch 2 Completed — Avg Train Loss: 5058.0620 | Avg Val Loss: 5207.2641 | Time Elapsed: 3.19 seconds
# Epoch 3 Completed — Avg Train Loss: 4749.2102 | Avg Val Loss: 5118.2315 | Time Elapsed: 3.20 seconds
# Epoch 4 Completed — Avg Train Loss: 4731.9822 | Avg Val Loss: 5113.6054 | Time Elapsed: 3.18 seconds
# Epoch 5 Completed — Avg Train Loss: 4727.0202 | Avg Val Loss: 5113.3845 | Time Elapsed: 3.18 seconds
# Epoch 6 Completed — Avg Train Loss: 4553.7778 | Avg Val Loss: 4017.1137 | Time Elapsed: 3.23 seconds
# Epoch 7 Completed — Avg Train Loss: 3854.6037 | Avg Val Loss: 4007.2961 | Time Elapsed: 3.18 seconds
# Epoch 8 Completed — Avg Train Loss: 3825.9338 | Avg Val Loss: 4006.6918 | Time Elapsed: 3.20 seconds
# Epoch 9 Completed — Avg Train Loss: 3812.2572 | Avg Val Loss: 3993.1243 | Time Elapsed: 3.18 seconds
# Epoch 10 Completed — Avg Train Loss: 3819.9888 | Avg Val Loss: 4010.5670 | Time Elapsed: 3.17 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'adam', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 2, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 32, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 3594.2889 | Avg Val Loss: 3308.6847 | Time Elapsed: 3.16 seconds
# Epoch 2 Completed — Avg Train Loss: 3146.1108 | Avg Val Loss: 3298.8108 | Time Elapsed: 3.21 seconds
# Epoch 3 Completed — Avg Train Loss: 3150.7367 | Avg Val Loss: 3324.0817 | Time Elapsed: 3.17 seconds
# Epoch 4 Completed — Avg Train Loss: 3150.2407 | Avg Val Loss: 3297.9811 | Time Elapsed: 3.19 seconds
# Epoch 5 Completed — Avg Train Loss: 3145.4560 | Avg Val Loss: 3287.6962 | Time Elapsed: 3.22 seconds
# Epoch 6 Completed — Avg Train Loss: 3148.5118 | Avg Val Loss: 3288.5515 | Time Elapsed: 3.19 seconds
# Epoch 7 Completed — Avg Train Loss: 3147.3838 | Avg Val Loss: 3283.6966 | Time Elapsed: 3.19 seconds
# Epoch 8 Completed — Avg Train Loss: 3149.3220 | Avg Val Loss: 3289.3162 | Time Elapsed: 3.17 seconds
# Epoch 9 Completed — Avg Train Loss: 3145.7942 | Avg Val Loss: 3332.6967 | Time Elapsed: 3.15 seconds
# Epoch 10 Completed — Avg Train Loss: 3150.3487 | Avg Val Loss: 3284.9236 | Time Elapsed: 3.18 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'adam', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 2, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 64, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 9244.4371 | Avg Val Loss: 9164.0058 | Time Elapsed: 1.87 seconds
# Epoch 2 Completed — Avg Train Loss: 7998.2645 | Avg Val Loss: 8280.6439 | Time Elapsed: 1.90 seconds
# Epoch 3 Completed — Avg Train Loss: 7408.2429 | Avg Val Loss: 7880.0914 | Time Elapsed: 1.85 seconds
# Epoch 4 Completed — Avg Train Loss: 7164.1959 | Avg Val Loss: 7728.7933 | Time Elapsed: 1.87 seconds
# Epoch 5 Completed — Avg Train Loss: 7089.1778 | Avg Val Loss: 7683.1941 | Time Elapsed: 1.87 seconds
# Epoch 6 Completed — Avg Train Loss: 7071.1947 | Avg Val Loss: 7671.8196 | Time Elapsed: 1.85 seconds
# Epoch 7 Completed — Avg Train Loss: 6847.3088 | Avg Val Loss: 4959.9166 | Time Elapsed: 1.92 seconds
# Epoch 8 Completed — Avg Train Loss: 4641.5230 | Avg Val Loss: 4992.7901 | Time Elapsed: 1.89 seconds
# Epoch 9 Completed — Avg Train Loss: 4645.1394 | Avg Val Loss: 4993.6981 | Time Elapsed: 1.85 seconds
# Epoch 10 Completed — Avg Train Loss: 4645.3122 | Avg Val Loss: 4994.8745 | Time Elapsed: 1.85 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'adam', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 2, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 64, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 7060.4573 | Avg Val Loss: 7036.7202 | Time Elapsed: 1.85 seconds
# Epoch 2 Completed — Avg Train Loss: 6661.2563 | Avg Val Loss: 7031.4631 | Time Elapsed: 1.86 seconds
# Epoch 3 Completed — Avg Train Loss: 6661.9129 | Avg Val Loss: 7035.1301 | Time Elapsed: 1.84 seconds
# Epoch 4 Completed — Avg Train Loss: 6660.5325 | Avg Val Loss: 7035.4497 | Time Elapsed: 1.85 seconds
# Epoch 5 Completed — Avg Train Loss: 6664.6697 | Avg Val Loss: 7035.3218 | Time Elapsed: 1.85 seconds
# Epoch 6 Completed — Avg Train Loss: 6661.8787 | Avg Val Loss: 7028.1241 | Time Elapsed: 1.88 seconds
# Epoch 7 Completed — Avg Train Loss: 6664.0711 | Avg Val Loss: 7029.8807 | Time Elapsed: 1.89 seconds
# Epoch 8 Completed — Avg Train Loss: 6661.9883 | Avg Val Loss: 7044.3637 | Time Elapsed: 1.88 seconds
# Epoch 9 Completed — Avg Train Loss: 6661.4988 | Avg Val Loss: 7033.5427 | Time Elapsed: 1.86 seconds
# Epoch 10 Completed — Avg Train Loss: 6665.5266 | Avg Val Loss: 7035.9789 | Time Elapsed: 1.88 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'adam', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 2, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 32, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 4163.8178 | Avg Val Loss: 3579.6856 | Time Elapsed: 2.23 seconds
# Epoch 2 Completed — Avg Train Loss: 2971.1859 | Avg Val Loss: 3074.3759 | Time Elapsed: 2.32 seconds
# Epoch 3 Completed — Avg Train Loss: 2797.8331 | Avg Val Loss: 3010.2162 | Time Elapsed: 2.25 seconds
# Epoch 4 Completed — Avg Train Loss: 2788.2808 | Avg Val Loss: 3005.9698 | Time Elapsed: 2.25 seconds
# Epoch 5 Completed — Avg Train Loss: 2790.3220 | Avg Val Loss: 3002.3519 | Time Elapsed: 2.26 seconds
# Epoch 6 Completed — Avg Train Loss: 2787.0658 | Avg Val Loss: 3005.0425 | Time Elapsed: 2.25 seconds
# Epoch 7 Completed — Avg Train Loss: 2787.4026 | Avg Val Loss: 3002.8353 | Time Elapsed: 2.23 seconds
# Epoch 8 Completed — Avg Train Loss: 2785.5587 | Avg Val Loss: 3005.5061 | Time Elapsed: 2.25 seconds
# Epoch 9 Completed — Avg Train Loss: 2785.7542 | Avg Val Loss: 3005.1934 | Time Elapsed: 2.23 seconds
# Epoch 10 Completed — Avg Train Loss: 2776.7825 | Avg Val Loss: 3011.9319 | Time Elapsed: 2.27 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'adam', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 2, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 32, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 4046.9053 | Avg Val Loss: 4159.2159 | Time Elapsed: 2.26 seconds
# Epoch 2 Completed — Avg Train Loss: 3945.9441 | Avg Val Loss: 4148.0942 | Time Elapsed: 2.26 seconds
# Epoch 3 Completed — Avg Train Loss: 3947.1580 | Avg Val Loss: 4155.4383 | Time Elapsed: 2.26 seconds
# Epoch 4 Completed — Avg Train Loss: 3947.1758 | Avg Val Loss: 4149.8362 | Time Elapsed: 2.25 seconds
# Epoch 5 Completed — Avg Train Loss: 3944.5983 | Avg Val Loss: 4148.9487 | Time Elapsed: 2.31 seconds
# Epoch 6 Completed — Avg Train Loss: 3945.7915 | Avg Val Loss: 4160.3614 | Time Elapsed: 2.26 seconds
# Epoch 7 Completed — Avg Train Loss: 3946.4529 | Avg Val Loss: 4152.4561 | Time Elapsed: 2.25 seconds
# Epoch 8 Completed — Avg Train Loss: 3943.7312 | Avg Val Loss: 4152.2464 | Time Elapsed: 2.26 seconds
# Epoch 9 Completed — Avg Train Loss: 3944.8119 | Avg Val Loss: 4167.6899 | Time Elapsed: 2.25 seconds
# Epoch 10 Completed — Avg Train Loss: 3946.7603 | Avg Val Loss: 4148.6382 | Time Elapsed: 2.25 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'adam', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 2, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 64, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 4735.1569 | Avg Val Loss: 4309.9132 | Time Elapsed: 1.33 seconds
# Epoch 2 Completed — Avg Train Loss: 3526.2152 | Avg Val Loss: 3468.3442 | Time Elapsed: 1.35 seconds
# Epoch 3 Completed — Avg Train Loss: 2980.9052 | Avg Val Loss: 3080.8942 | Time Elapsed: 1.34 seconds
# Epoch 4 Completed — Avg Train Loss: 2759.7225 | Avg Val Loss: 2928.8000 | Time Elapsed: 1.35 seconds
# Epoch 5 Completed — Avg Train Loss: 2688.5299 | Avg Val Loss: 2877.6443 | Time Elapsed: 1.40 seconds
# Epoch 6 Completed — Avg Train Loss: 2670.1556 | Avg Val Loss: 2863.2808 | Time Elapsed: 1.35 seconds
# Epoch 7 Completed — Avg Train Loss: 2665.8098 | Avg Val Loss: 2859.1243 | Time Elapsed: 1.35 seconds
# Epoch 8 Completed — Avg Train Loss: 2667.9023 | Avg Val Loss: 2858.1213 | Time Elapsed: 1.36 seconds
# Epoch 9 Completed — Avg Train Loss: 2669.0629 | Avg Val Loss: 2857.2559 | Time Elapsed: 1.35 seconds
# Epoch 10 Completed — Avg Train Loss: 2665.3248 | Avg Val Loss: 2858.8084 | Time Elapsed: 1.34 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model RNNRUL params: {'opt': 'adam', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 2, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 64, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 3784.6439 | Avg Val Loss: 3738.5126 | Time Elapsed: 1.37 seconds
# Epoch 2 Completed — Avg Train Loss: 3498.6117 | Avg Val Loss: 3739.4874 | Time Elapsed: 1.40 seconds
# Epoch 3 Completed — Avg Train Loss: 3498.0898 | Avg Val Loss: 3745.7344 | Time Elapsed: 1.38 seconds
# Epoch 4 Completed — Avg Train Loss: 3495.9406 | Avg Val Loss: 3741.4102 | Time Elapsed: 1.35 seconds
# Epoch 5 Completed — Avg Train Loss: 3496.1521 | Avg Val Loss: 3738.8544 | Time Elapsed: 1.35 seconds
# Epoch 6 Completed — Avg Train Loss: 3497.0184 | Avg Val Loss: 3739.8348 | Time Elapsed: 1.36 seconds
# Epoch 7 Completed — Avg Train Loss: 3498.7513 | Avg Val Loss: 3738.2351 | Time Elapsed: 1.37 seconds
# Epoch 8 Completed — Avg Train Loss: 3496.9040 | Avg Val Loss: 3742.5259 | Time Elapsed: 1.34 seconds
# Epoch 9 Completed — Avg Train Loss: 3495.8346 | Avg Val Loss: 3739.2488 | Time Elapsed: 1.35 seconds
# Epoch 10 Completed — Avg Train Loss: 3499.7111 | Avg Val Loss: 3736.0461 | Time Elapsed: 1.34 seconds
# ------------------------------------------------------------
#
# ✅ Grid Search Complete
# Best Params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 2, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 32, 'lr': 0.01, 'epochs': 10}
# Best Val Loss: 1199.4660
#
# 🔎 Training with model LSTMRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 32, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 6335.2747 | Avg Val Loss: 4389.7714 | Time Elapsed: 3.12 seconds
# Epoch 2 Completed — Avg Train Loss: 2834.2931 | Avg Val Loss: 2031.2980 | Time Elapsed: 3.13 seconds
# Epoch 3 Completed — Avg Train Loss: 1500.6311 | Avg Val Loss: 1499.9421 | Time Elapsed: 3.14 seconds
# Epoch 4 Completed — Avg Train Loss: 1070.7467 | Avg Val Loss: 898.4782 | Time Elapsed: 3.13 seconds
# Epoch 5 Completed — Avg Train Loss: 919.0359 | Avg Val Loss: 1038.4594 | Time Elapsed: 3.10 seconds
# Epoch 6 Completed — Avg Train Loss: 837.4623 | Avg Val Loss: 1000.9276 | Time Elapsed: 3.16 seconds
# Epoch 7 Completed — Avg Train Loss: 781.0632 | Avg Val Loss: 684.5909 | Time Elapsed: 3.11 seconds
# Epoch 8 Completed — Avg Train Loss: 713.5973 | Avg Val Loss: 865.3409 | Time Elapsed: 3.12 seconds
# Epoch 9 Completed — Avg Train Loss: 639.6600 | Avg Val Loss: 797.2207 | Time Elapsed: 3.10 seconds
# Epoch 10 Completed — Avg Train Loss: 526.5922 | Avg Val Loss: 888.7522 | Time Elapsed: 3.10 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model LSTMRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 32, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 2371.2103 | Avg Val Loss: 1611.2460 | Time Elapsed: 3.13 seconds
# Epoch 2 Completed — Avg Train Loss: 1222.5886 | Avg Val Loss: 1372.5014 | Time Elapsed: 3.16 seconds
# Epoch 3 Completed — Avg Train Loss: 862.9513 | Avg Val Loss: 1504.4213 | Time Elapsed: 3.14 seconds
# Epoch 4 Completed — Avg Train Loss: 616.8270 | Avg Val Loss: 1725.6204 | Time Elapsed: 3.13 seconds
# Epoch 5 Completed — Avg Train Loss: 533.4497 | Avg Val Loss: 2060.2642 | Time Elapsed: 3.16 seconds
# Epoch 6 Completed — Avg Train Loss: 480.4344 | Avg Val Loss: 1613.2365 | Time Elapsed: 3.15 seconds
# Epoch 7 Completed — Avg Train Loss: 447.4510 | Avg Val Loss: 1690.9256 | Time Elapsed: 3.15 seconds
# Epoch 8 Completed — Avg Train Loss: 395.0282 | Avg Val Loss: 1656.5311 | Time Elapsed: 3.12 seconds
# Epoch 9 Completed — Avg Train Loss: 397.8065 | Avg Val Loss: 2943.6420 | Time Elapsed: 3.13 seconds
# Epoch 10 Completed — Avg Train Loss: 400.5440 | Avg Val Loss: 1950.2294 | Time Elapsed: 3.13 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model LSTMRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 64, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 8755.3211 | Avg Val Loss: 8324.7088 | Time Elapsed: 1.86 seconds
# Epoch 2 Completed — Avg Train Loss: 6890.0293 | Avg Val Loss: 6670.4298 | Time Elapsed: 1.88 seconds
# Epoch 3 Completed — Avg Train Loss: 5209.7085 | Avg Val Loss: 2981.0536 | Time Elapsed: 1.85 seconds
# Epoch 4 Completed — Avg Train Loss: 2250.3593 | Avg Val Loss: 2104.2785 | Time Elapsed: 1.85 seconds
# Epoch 5 Completed — Avg Train Loss: 1601.4930 | Avg Val Loss: 1941.8103 | Time Elapsed: 1.85 seconds
# Epoch 6 Completed — Avg Train Loss: 1220.5426 | Avg Val Loss: 1562.7531 | Time Elapsed: 1.82 seconds
# Epoch 7 Completed — Avg Train Loss: 999.1169 | Avg Val Loss: 1348.0381 | Time Elapsed: 1.89 seconds
# Epoch 8 Completed — Avg Train Loss: 905.6485 | Avg Val Loss: 789.2924 | Time Elapsed: 1.87 seconds
# Epoch 9 Completed — Avg Train Loss: 824.3951 | Avg Val Loss: 876.9105 | Time Elapsed: 1.83 seconds
# Epoch 10 Completed — Avg Train Loss: 759.7003 | Avg Val Loss: 930.8430 | Time Elapsed: 1.85 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model LSTMRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 50, 'batch_size': 64, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 3451.1979 | Avg Val Loss: 3282.5522 | Time Elapsed: 1.87 seconds
# Epoch 2 Completed — Avg Train Loss: 1719.0123 | Avg Val Loss: 1269.4828 | Time Elapsed: 1.85 seconds
# Epoch 3 Completed — Avg Train Loss: 1035.1936 | Avg Val Loss: 4732.5996 | Time Elapsed: 1.84 seconds
# Epoch 4 Completed — Avg Train Loss: 627.9721 | Avg Val Loss: 2460.6596 | Time Elapsed: 1.85 seconds
# Epoch 5 Completed — Avg Train Loss: 430.5750 | Avg Val Loss: 1279.6018 | Time Elapsed: 1.84 seconds
# Epoch 6 Completed — Avg Train Loss: 347.7062 | Avg Val Loss: 3594.2386 | Time Elapsed: 1.86 seconds
# Epoch 7 Completed — Avg Train Loss: 300.3446 | Avg Val Loss: 1532.2240 | Time Elapsed: 1.86 seconds
# Epoch 8 Completed — Avg Train Loss: 282.8912 | Avg Val Loss: 1538.4182 | Time Elapsed: 1.87 seconds
# Epoch 9 Completed — Avg Train Loss: 249.9396 | Avg Val Loss: 1355.5480 | Time Elapsed: 1.86 seconds
# Epoch 10 Completed — Avg Train Loss: 236.6882 | Avg Val Loss: 1405.7113 | Time Elapsed: 1.86 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model LSTMRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 32, 'lr': 0.001, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 3810.8076 | Avg Val Loss: 2707.9775 | Time Elapsed: 2.21 seconds
# Epoch 2 Completed — Avg Train Loss: 1829.4336 | Avg Val Loss: 1340.2921 | Time Elapsed: 2.26 seconds
# Epoch 3 Completed — Avg Train Loss: 992.9603 | Avg Val Loss: 826.4330 | Time Elapsed: 2.25 seconds
# Epoch 4 Completed — Avg Train Loss: 624.1442 | Avg Val Loss: 2391.6381 | Time Elapsed: 2.21 seconds
# Epoch 5 Completed — Avg Train Loss: 484.0750 | Avg Val Loss: 417.6990 | Time Elapsed: 2.25 seconds
# Epoch 6 Completed — Avg Train Loss: 416.2307 | Avg Val Loss: 327.8922 | Time Elapsed: 2.23 seconds
# Epoch 7 Completed — Avg Train Loss: 387.5774 | Avg Val Loss: 593.8405 | Time Elapsed: 2.20 seconds
# Epoch 8 Completed — Avg Train Loss: 364.1859 | Avg Val Loss: 1402.5730 | Time Elapsed: 2.23 seconds
# Epoch 9 Completed — Avg Train Loss: 341.6748 | Avg Val Loss: 879.6598 | Time Elapsed: 2.22 seconds
# Epoch 10 Completed — Avg Train Loss: 318.7620 | Avg Val Loss: 471.8954 | Time Elapsed: 2.23 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model LSTMRUL params: {'opt': 'rms', 'hidden_dim1': 128, 'hidden_dim2': 64, 'num_layers': 1, 'dropout': 0.1, 'seq_len': 100, 'batch_size': 32, 'lr': 0.01, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 1732.6116 | Avg Val Loss: 786.1031 | Time Elapsed: 2.26 seconds
# Epoch 2 Completed — Avg Train Loss: 839.3476 | Avg Val Loss: 1446.0898 | Time Elapsed: 2.23 seconds
# Epoch 3 Completed — Avg Train Loss: 795.3737 | Avg Val Loss: 929.8078 | Time Elapsed: 2.25 seconds
# Epoch 4 Completed — Avg Train Loss: 789.2013 | Avg Val Loss: 875.7728 | Time Elapsed: 2.23 seconds
# Epoch 5 Completed — Avg Train Loss: 543.5417 | Avg Val Loss: 607.9182 | Time Elapsed: 2.28 seconds
# Epoch 6 Completed — Avg Train Loss: 347.9104 | Avg Val Loss: 750.7259 | Time Elapsed: 2.25 seconds
# Epoch 7 Completed — Avg Train Loss: 297.6515 | Avg Val Loss: 3049.1357 | Time Elapsed: 2.22 seconds
# Epoch 8 Completed — Avg Train Loss: 265.9122 | Avg Val Loss: 610.4912 | Time Elapsed: 2.26 seconds
# Epoch 9 Completed — Avg Train Loss: 281.5326 | Avg Val Loss: 529.8072 | Time Elapsed: 2.23 seconds
# Epoch 10 Completed — Avg Train Loss: 220.4599 | Avg Val Loss: 557.1540 | Time Elapsed: 2.22 seconds
# ------------------------------------------------------------
#
# ...
# Epoch 2 Completed — Avg Train Loss: 2141.0133 | Avg Val Loss: 2098.1861 | Time Elapsed: 2.21 seconds
# Epoch 3 Completed — Avg Train Loss: 2013.7218 | Avg Val Loss: 2065.2815 | Time Elapsed: 2.21 seconds
# Epoch 4 Completed — Avg Train Loss: 2013.0369 | Avg Val Loss: 2071.6196 | Time Elapsed: 2.20 seconds
# Epoch 5 Completed — Avg Train Loss: 2012.9270 | Avg Val Loss: 2063.2579 | Time Elapsed: 2.21 seconds
# Epoch 6 Completed — Avg Train Loss: 2011.4396 | Avg Val Loss: 2064.3412 | Time Elapsed: 2.20 seconds
# Epoch 7 Completed — Avg Train Loss: 2013.3745 | Avg Val Loss: 2060.7863 | Time Elapsed: 2.21 seconds
# Epoch 8 Completed — Avg Train Loss: 2012.3149 | Avg Val Loss: 2060.7577 | Time Elapsed: 2.21 seconds
# Epoch 9 Completed — Avg Train Loss: 2013.1576 | Avg Val Loss: 2061.5543 | Time Elapsed: 2.21 seconds
# Epoch 10 Completed — Avg Train Loss: 2011.9691 | Avg Val Loss: 2068.9132 | Time Elapsed: 2.22 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model InformerRUL params: {'opt': 'adam', 'seq_len': 100, 'batch_size': 64, 'lr': 0.001, 'd_model': 128, 'n_heads': 2, 'num_layers': 1, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 3217.3360 | Avg Val Loss: 2118.7199 | Time Elapsed: 1.53 seconds
# Epoch 2 Completed — Avg Train Loss: 1549.8767 | Avg Val Loss: 992.4654 | Time Elapsed: 1.53 seconds
# Epoch 3 Completed — Avg Train Loss: 941.0295 | Avg Val Loss: 757.3425 | Time Elapsed: 1.53 seconds
# Epoch 4 Completed — Avg Train Loss: 825.1660 | Avg Val Loss: 848.5327 | Time Elapsed: 1.53 seconds
# Epoch 5 Completed — Avg Train Loss: 776.5921 | Avg Val Loss: 777.8983 | Time Elapsed: 1.54 seconds
# Epoch 6 Completed — Avg Train Loss: 739.2042 | Avg Val Loss: 712.4144 | Time Elapsed: 1.53 seconds
# Epoch 7 Completed — Avg Train Loss: 646.0008 | Avg Val Loss: 523.9615 | Time Elapsed: 1.53 seconds
# Epoch 8 Completed — Avg Train Loss: 561.6285 | Avg Val Loss: 497.6017 | Time Elapsed: 1.53 seconds
# Epoch 9 Completed — Avg Train Loss: 482.8643 | Avg Val Loss: 449.7393 | Time Elapsed: 1.53 seconds
# Epoch 10 Completed — Avg Train Loss: 438.7717 | Avg Val Loss: 462.4627 | Time Elapsed: 1.53 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model InformerRUL params: {'opt': 'adam', 'seq_len': 100, 'batch_size': 64, 'lr': 0.001, 'd_model': 128, 'n_heads': 2, 'num_layers': 2, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 3229.3972 | Avg Val Loss: 2137.8832 | Time Elapsed: 2.23 seconds
# Epoch 2 Completed — Avg Train Loss: 2016.7518 | Avg Val Loss: 2061.4551 | Time Elapsed: 2.21 seconds
# Epoch 3 Completed — Avg Train Loss: 2013.2191 | Avg Val Loss: 2066.0581 | Time Elapsed: 2.22 seconds
# Epoch 4 Completed — Avg Train Loss: 2012.6874 | Avg Val Loss: 1902.9115 | Time Elapsed: 2.23 seconds
# Epoch 5 Completed — Avg Train Loss: 2014.2745 | Avg Val Loss: 2042.2726 | Time Elapsed: 2.23 seconds
# Epoch 6 Completed — Avg Train Loss: 1482.3952 | Avg Val Loss: 1531.6950 | Time Elapsed: 2.23 seconds
# Epoch 7 Completed — Avg Train Loss: 1414.3170 | Avg Val Loss: 1465.5485 | Time Elapsed: 2.22 seconds
# Epoch 8 Completed — Avg Train Loss: 1392.1182 | Avg Val Loss: 1461.1519 | Time Elapsed: 2.20 seconds
# Epoch 9 Completed — Avg Train Loss: 1390.1032 | Avg Val Loss: 1475.8021 | Time Elapsed: 2.21 seconds
# Epoch 10 Completed — Avg Train Loss: 1376.8577 | Avg Val Loss: 1451.6595 | Time Elapsed: 2.22 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model InformerRUL params: {'opt': 'adam', 'seq_len': 100, 'batch_size': 64, 'lr': 0.001, 'd_model': 128, 'n_heads': 4, 'num_layers': 1, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 3213.2618 | Avg Val Loss: 2025.2769 | Time Elapsed: 1.53 seconds
# Epoch 2 Completed — Avg Train Loss: 1405.8933 | Avg Val Loss: 917.8239 | Time Elapsed: 1.55 seconds
# Epoch 3 Completed — Avg Train Loss: 893.0407 | Avg Val Loss: 739.4128 | Time Elapsed: 1.53 seconds
# Epoch 4 Completed — Avg Train Loss: 733.5370 | Avg Val Loss: 729.1497 | Time Elapsed: 1.54 seconds
# Epoch 5 Completed — Avg Train Loss: 573.2681 | Avg Val Loss: 493.1519 | Time Elapsed: 1.53 seconds
# Epoch 6 Completed — Avg Train Loss: 443.9625 | Avg Val Loss: 343.3334 | Time Elapsed: 1.55 seconds
# Epoch 7 Completed — Avg Train Loss: 364.1405 | Avg Val Loss: 320.3478 | Time Elapsed: 1.55 seconds
# Epoch 8 Completed — Avg Train Loss: 346.9091 | Avg Val Loss: 344.8771 | Time Elapsed: 1.54 seconds
# Epoch 9 Completed — Avg Train Loss: 312.9757 | Avg Val Loss: 324.9502 | Time Elapsed: 1.55 seconds
# Epoch 10 Completed — Avg Train Loss: 304.3188 | Avg Val Loss: 329.4313 | Time Elapsed: 1.53 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model InformerRUL params: {'opt': 'adam', 'seq_len': 100, 'batch_size': 64, 'lr': 0.001, 'd_model': 128, 'n_heads': 4, 'num_layers': 2, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 3229.1281 | Avg Val Loss: 2134.6135 | Time Elapsed: 2.23 seconds
# Epoch 2 Completed — Avg Train Loss: 1813.6162 | Avg Val Loss: 2069.5230 | Time Elapsed: 2.24 seconds
# Epoch 3 Completed — Avg Train Loss: 2015.8593 | Avg Val Loss: 2060.5828 | Time Elapsed: 2.22 seconds
# Epoch 4 Completed — Avg Train Loss: 2014.0976 | Avg Val Loss: 2061.1265 | Time Elapsed: 2.22 seconds
# Epoch 5 Completed — Avg Train Loss: 1978.7150 | Avg Val Loss: 2057.9798 | Time Elapsed: 2.23 seconds
# Epoch 6 Completed — Avg Train Loss: 1775.1438 | Avg Val Loss: 2064.5576 | Time Elapsed: 2.23 seconds
# Epoch 7 Completed — Avg Train Loss: 2011.2185 | Avg Val Loss: 2061.5726 | Time Elapsed: 2.22 seconds
# Epoch 8 Completed — Avg Train Loss: 2012.2217 | Avg Val Loss: 2064.8341 | Time Elapsed: 2.22 seconds
# Epoch 9 Completed — Avg Train Loss: 2010.4167 | Avg Val Loss: 2060.6472 | Time Elapsed: 2.22 seconds
# Epoch 10 Completed — Avg Train Loss: 2009.6458 | Avg Val Loss: 2059.9533 | Time Elapsed: 2.23 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model InformerRUL params: {'opt': 'adam', 'seq_len': 100, 'batch_size': 64, 'lr': 0.01, 'd_model': 64, 'n_heads': 2, 'num_layers': 1, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 2266.5581 | Avg Val Loss: 2079.0076 | Time Elapsed: 1.52 seconds
# Epoch 2 Completed — Avg Train Loss: 2020.8886 | Avg Val Loss: 2063.3800 | Time Elapsed: 1.52 seconds
# Epoch 3 Completed — Avg Train Loss: 2015.0211 | Avg Val Loss: 2068.5899 | Time Elapsed: 1.53 seconds
# Epoch 4 Completed — Avg Train Loss: 2017.4971 | Avg Val Loss: 2063.4852 | Time Elapsed: 1.53 seconds
# Epoch 5 Completed — Avg Train Loss: 2017.7546 | Avg Val Loss: 2062.8347 | Time Elapsed: 1.53 seconds
# Epoch 6 Completed — Avg Train Loss: 2017.0381 | Avg Val Loss: 2061.2930 | Time Elapsed: 1.53 seconds
# Epoch 7 Completed — Avg Train Loss: 2019.3583 | Avg Val Loss: 2063.2310 | Time Elapsed: 1.52 seconds
# Epoch 8 Completed — Avg Train Loss: 2016.9870 | Avg Val Loss: 2067.4903 | Time Elapsed: 1.53 seconds
# Epoch 9 Completed — Avg Train Loss: 2017.0744 | Avg Val Loss: 2062.9667 | Time Elapsed: 1.52 seconds
# Epoch 10 Completed — Avg Train Loss: 2018.7537 | Avg Val Loss: 2061.5167 | Time Elapsed: 1.53 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model InformerRUL params: {'opt': 'adam', 'seq_len': 100, 'batch_size': 64, 'lr': 0.01, 'd_model': 64, 'n_heads': 2, 'num_layers': 2, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 2260.0008 | Avg Val Loss: 2060.9761 | Time Elapsed: 2.21 seconds
# Epoch 2 Completed — Avg Train Loss: 2015.0181 | Avg Val Loss: 2062.4306 | Time Elapsed: 2.21 seconds
# Epoch 3 Completed — Avg Train Loss: 2015.8546 | Avg Val Loss: 2072.8900 | Time Elapsed: 2.21 seconds
# Epoch 4 Completed — Avg Train Loss: 2016.3325 | Avg Val Loss: 2061.6163 | Time Elapsed: 2.21 seconds
# Epoch 5 Completed — Avg Train Loss: 2017.1297 | Avg Val Loss: 2068.8662 | Time Elapsed: 2.22 seconds
# Epoch 6 Completed — Avg Train Loss: 2017.7978 | Avg Val Loss: 2062.8841 | Time Elapsed: 2.21 seconds
# Epoch 7 Completed — Avg Train Loss: 2018.1762 | Avg Val Loss: 2061.7435 | Time Elapsed: 2.20 seconds
# Epoch 8 Completed — Avg Train Loss: 2017.1256 | Avg Val Loss: 2070.8201 | Time Elapsed: 2.19 seconds
# Epoch 9 Completed — Avg Train Loss: 2016.8797 | Avg Val Loss: 2061.0713 | Time Elapsed: 2.21 seconds
# Epoch 10 Completed — Avg Train Loss: 2018.5880 | Avg Val Loss: 2064.5429 | Time Elapsed: 2.19 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model InformerRUL params: {'opt': 'adam', 'seq_len': 100, 'batch_size': 64, 'lr': 0.01, 'd_model': 64, 'n_heads': 4, 'num_layers': 1, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 2269.5123 | Avg Val Loss: 2062.2772 | Time Elapsed: 1.52 seconds
# Epoch 2 Completed — Avg Train Loss: 2015.4260 | Avg Val Loss: 2067.1718 | Time Elapsed: 1.52 seconds
# Epoch 3 Completed — Avg Train Loss: 2015.9713 | Avg Val Loss: 2060.9271 | Time Elapsed: 1.52 seconds
# Epoch 4 Completed — Avg Train Loss: 2014.7588 | Avg Val Loss: 2075.6989 | Time Elapsed: 1.51 seconds
# Epoch 5 Completed — Avg Train Loss: 2014.6206 | Avg Val Loss: 2060.9889 | Time Elapsed: 1.52 seconds
# Epoch 6 Completed — Avg Train Loss: 2016.9970 | Avg Val Loss: 2061.2412 | Time Elapsed: 1.52 seconds
# Epoch 7 Completed — Avg Train Loss: 2016.8661 | Avg Val Loss: 2063.6913 | Time Elapsed: 1.53 seconds
# Epoch 8 Completed — Avg Train Loss: 2018.5702 | Avg Val Loss: 2062.4797 | Time Elapsed: 1.52 seconds
# Epoch 9 Completed — Avg Train Loss: 2015.7539 | Avg Val Loss: 2061.3541 | Time Elapsed: 1.53 seconds
# Epoch 10 Completed — Avg Train Loss: 2017.6912 | Avg Val Loss: 2087.1548 | Time Elapsed: 1.51 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model InformerRUL params: {'opt': 'adam', 'seq_len': 100, 'batch_size': 64, 'lr': 0.01, 'd_model': 64, 'n_heads': 4, 'num_layers': 2, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 2254.5119 | Avg Val Loss: 2061.1805 | Time Elapsed: 2.21 seconds
# Epoch 2 Completed — Avg Train Loss: 2016.6058 | Avg Val Loss: 2062.1396 | Time Elapsed: 2.21 seconds
# Epoch 3 Completed — Avg Train Loss: 2014.9203 | Avg Val Loss: 2067.1379 | Time Elapsed: 2.22 seconds
# Epoch 4 Completed — Avg Train Loss: 2015.8919 | Avg Val Loss: 2060.9550 | Time Elapsed: 2.20 seconds
# Epoch 5 Completed — Avg Train Loss: 2014.6547 | Avg Val Loss: 2085.5901 | Time Elapsed: 2.21 seconds
# Epoch 6 Completed — Avg Train Loss: 2019.1673 | Avg Val Loss: 2061.8725 | Time Elapsed: 2.21 seconds
# Epoch 7 Completed — Avg Train Loss: 2015.4075 | Avg Val Loss: 2063.0505 | Time Elapsed: 2.21 seconds
# Epoch 8 Completed — Avg Train Loss: 2016.6410 | Avg Val Loss: 2068.3069 | Time Elapsed: 2.21 seconds
# Epoch 9 Completed — Avg Train Loss: 2017.0053 | Avg Val Loss: 2067.0674 | Time Elapsed: 2.20 seconds
# Epoch 10 Completed — Avg Train Loss: 2016.3659 | Avg Val Loss: 2065.0397 | Time Elapsed: 2.20 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model InformerRUL params: {'opt': 'adam', 'seq_len': 100, 'batch_size': 64, 'lr': 0.01, 'd_model': 128, 'n_heads': 2, 'num_layers': 1, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 2170.8243 | Avg Val Loss: 2098.7896 | Time Elapsed: 1.55 seconds
# Epoch 2 Completed — Avg Train Loss: 2018.0959 | Avg Val Loss: 2060.3337 | Time Elapsed: 1.53 seconds
# Epoch 3 Completed — Avg Train Loss: 2015.9612 | Avg Val Loss: 2079.9750 | Time Elapsed: 1.53 seconds
# Epoch 4 Completed — Avg Train Loss: 2019.6208 | Avg Val Loss: 2060.2271 | Time Elapsed: 1.54 seconds
# Epoch 5 Completed — Avg Train Loss: 2017.7872 | Avg Val Loss: 2070.0734 | Time Elapsed: 1.53 seconds
# Epoch 6 Completed — Avg Train Loss: 2018.9023 | Avg Val Loss: 2068.0315 | Time Elapsed: 1.53 seconds
# Epoch 7 Completed — Avg Train Loss: 2016.2832 | Avg Val Loss: 2062.1628 | Time Elapsed: 1.54 seconds
# Epoch 8 Completed — Avg Train Loss: 2020.4926 | Avg Val Loss: 2053.6745 | Time Elapsed: 1.53 seconds
# Epoch 9 Completed — Avg Train Loss: 2014.7688 | Avg Val Loss: 2061.4464 | Time Elapsed: 1.53 seconds
# Epoch 10 Completed — Avg Train Loss: 2014.8836 | Avg Val Loss: 2061.4475 | Time Elapsed: 1.54 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model InformerRUL params: {'opt': 'adam', 'seq_len': 100, 'batch_size': 64, 'lr': 0.01, 'd_model': 128, 'n_heads': 2, 'num_layers': 2, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 2162.6952 | Avg Val Loss: 2062.8610 | Time Elapsed: 2.23 seconds
# Epoch 2 Completed — Avg Train Loss: 2017.1166 | Avg Val Loss: 2061.8041 | Time Elapsed: 2.22 seconds
# Epoch 3 Completed — Avg Train Loss: 2016.6567 | Avg Val Loss: 2077.8908 | Time Elapsed: 2.22 seconds
# Epoch 4 Completed — Avg Train Loss: 2018.0063 | Avg Val Loss: 2061.2197 | Time Elapsed: 2.22 seconds
# Epoch 5 Completed — Avg Train Loss: 2018.8830 | Avg Val Loss: 2061.2050 | Time Elapsed: 2.22 seconds
# Epoch 6 Completed — Avg Train Loss: 2024.9768 | Avg Val Loss: 2061.1165 | Time Elapsed: 2.22 seconds
# Epoch 7 Completed — Avg Train Loss: 2020.5229 | Avg Val Loss: 2078.5075 | Time Elapsed: 2.21 seconds
# Epoch 8 Completed — Avg Train Loss: 2020.5304 | Avg Val Loss: 2062.0334 | Time Elapsed: 2.21 seconds
# Epoch 9 Completed — Avg Train Loss: 2017.3403 | Avg Val Loss: 2061.4550 | Time Elapsed: 2.22 seconds
# Epoch 10 Completed — Avg Train Loss: 2019.0583 | Avg Val Loss: 2060.9511 | Time Elapsed: 2.22 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model InformerRUL params: {'opt': 'adam', 'seq_len': 100, 'batch_size': 64, 'lr': 0.01, 'd_model': 128, 'n_heads': 4, 'num_layers': 1, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 2184.7788 | Avg Val Loss: 2066.2871 | Time Elapsed: 1.54 seconds
# Epoch 2 Completed — Avg Train Loss: 2016.9709 | Avg Val Loss: 2061.1779 | Time Elapsed: 1.53 seconds
# Epoch 3 Completed — Avg Train Loss: 2020.6350 | Avg Val Loss: 2061.2406 | Time Elapsed: 1.53 seconds
# Epoch 4 Completed — Avg Train Loss: 2018.0129 | Avg Val Loss: 2061.3373 | Time Elapsed: 1.53 seconds
# Epoch 5 Completed — Avg Train Loss: 2017.2462 | Avg Val Loss: 2063.4670 | Time Elapsed: 1.55 seconds
# Epoch 6 Completed — Avg Train Loss: 2019.6290 | Avg Val Loss: 2063.0604 | Time Elapsed: 1.53 seconds
# Epoch 7 Completed — Avg Train Loss: 2018.8527 | Avg Val Loss: 2084.7549 | Time Elapsed: 1.55 seconds
# Epoch 8 Completed — Avg Train Loss: 2020.1040 | Avg Val Loss: 2061.9283 | Time Elapsed: 1.54 seconds
# Epoch 9 Completed — Avg Train Loss: 2017.2557 | Avg Val Loss: 2076.0119 | Time Elapsed: 1.54 seconds
# Epoch 10 Completed — Avg Train Loss: 2020.4932 | Avg Val Loss: 2112.2989 | Time Elapsed: 1.55 seconds
# ------------------------------------------------------------
#
# 🔎 Training with model InformerRUL params: {'opt': 'adam', 'seq_len': 100, 'batch_size': 64, 'lr': 0.01, 'd_model': 128, 'n_heads': 4, 'num_layers': 2, 'epochs': 10}
# Epoch 1 Completed — Avg Train Loss: 2167.6264 | Avg Val Loss: 2061.9526 | Time Elapsed: 2.23 seconds
# Epoch 2 Completed — Avg Train Loss: 2018.6589 | Avg Val Loss: 2061.6903 | Time Elapsed: 2.23 seconds
# Epoch 3 Completed — Avg Train Loss: 2019.9225 | Avg Val Loss: 2062.5464 | Time Elapsed: 2.22 seconds
# Epoch 4 Completed — Avg Train Loss: 2017.3552 | Avg Val Loss: 2063.4331 | Time Elapsed: 2.25 seconds
# Epoch 5 Completed — Avg Train Loss: 2019.1599 | Avg Val Loss: 2065.6439 | Time Elapsed: 2.23 seconds
# Epoch 6 Completed — Avg Train Loss: 2020.3632 | Avg Val Loss: 2064.5516 | Time Elapsed: 2.23 seconds
# Epoch 7 Completed — Avg Train Loss: 2021.0189 | Avg Val Loss: 2093.0925 | Time Elapsed: 2.23 seconds
# Epoch 8 Completed — Avg Train Loss: 2020.3857 | Avg Val Loss: 2080.1519 | Time Elapsed: 2.22 seconds
# Epoch 9 Completed — Avg Train Loss: 2017.1469 | Avg Val Loss: 2089.7462 | Time Elapsed: 2.23 seconds
# Epoch 10 Completed — Avg Train Loss: 2018.4574 | Avg Val Loss: 2065.1959 | Time Elapsed: 2.23 seconds
# ------------------------------------------------------------
#
# ✅ Grid Search Complete
# Best Params: {'opt': 'rms', 'seq_len': 100, 'batch_size': 32, 'lr': 0.001, 'd_model': 128, 'n_heads': 2, 'num_layers': 1, 'epochs': 10}
# Best Val Loss: 329.4313

# %% [markdown]
# ## Check performance in MLflow UI.
# Run in terminal `mlflow ui --port 5000`
#
# Open `http://127.0.0.1:5000/` in browser.

# %%
# summary = []

# for model_name, info in model_results.items():
#     # pick best (lowest val_loss) from results
#     best_params, best_loss = min(info["results"], key=lambda x: x[1])
#     summary.append({
#         "Model": model_name,
#         "Best Params": best_params,
#         "Best Val Loss": best_loss
#     })

# df_summary = pd.DataFrame(summary)
# df_summary

# %%
# model_results

# %%
# %% [markdown]
# ## 7. Run Training

num_features=len(train_dataset.features)
params = {
        "input_dim": num_features,
        "hidden_dim1": 128,
        "hidden_dim2": 64,
        "num_layers": 1,
        "dropout": 0.2,
        }

models = {
    "RNN": RNNRUL(**params),
    "LSTM": LSTMRUL(**params),
    "Seq2Seq": Seq2SeqRUL(**params),
}

lr = 1e-3
epochs = 5
model_name = "Seq2Seq"   # <-- change to "Informer", "RNN", "LSTM", or "Seq2Seq"
# model_names = ["LSTM"]   # <-- change to "Informer", "RNN", "LSTM", or "Seq2Seq"
device="cuda" if torch.cuda.is_available() else "cpu"

print(f"Using device: {device}")

model = models[model_name]

print("Starting training...")
train_preds, train_true_rul, val_preds, val_true_rul, train_loss, val_loss = train_model(
            model, train_loader, val_loader,
            epochs=epochs,
            lr=lr,
            opt="rms",
            device=device
        )
print("Training completed.")

# Save parameters
torch.save(model.state_dict(), "model/model.pth")
# Out:
# Using device: cuda
# Starting training...
# Epoch 1 Completed — Avg Train Loss: 3865.3304 | Avg Val Loss: 2896.9564 | Time Elapsed: 2.59 seconds
# Epoch 2 Completed — Avg Train Loss: 1955.7377 | Avg Val Loss: 1475.2775 | Time Elapsed: 2.32 seconds
# Epoch 3 Completed — Avg Train Loss: 1100.8723 | Avg Val Loss: 1010.5955 | Time Elapsed: 2.34 seconds
# Epoch 4 Completed — Avg Train Loss: 805.6251 | Avg Val Loss: 809.8106 | Time Elapsed: 2.32 seconds
# Epoch 5 Completed — Avg Train Loss: 626.8267 | Avg Val Loss: 508.5510 | Time Elapsed: 2.34 seconds
# ------------------------------------------------------------
# Training completed.

# %%
model = models[model_name]
model
# Out:
# Seq2SeqRUL(
#   (encoder1): LSTM(24, 128, batch_first=True)
#   (bn): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (encoder2): LSTM(128, 64, batch_first=True)
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (relu): ReLU()
#   (fc): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
summary(model, input_size=(32, 100, len(train_dataset.features)))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Seq2SeqRUL                               [32]                      --
# ├─LSTM: 1-1                              [32, 100, 128]            78,848
# ├─BatchNorm1d: 1-2                       [32, 128]                 256
# ├─Dropout: 1-3                           [32, 128]                 --
# ├─LSTM: 1-4                              [32, 1, 64]               49,664
# ├─Dropout: 1-5                           [32, 64]                  --
# ├─Linear: 1-6                            [32, 1]                   65
# ├─ReLU: 1-7                              [32, 1]                   --
# ==========================================================================================
# Total params: 128,833
# Trainable params: 128,833
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 253.91
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 3.33
# Params size (MB): 0.52
# Estimated Total Size (MB): 4.15
# ==========================================================================================

# %%
# plt.figure(figsize=(14,6))
# train_preds, train_true_rul, val_preds, val_true_rul, train_loss, val_loss
# # Training
# plt.subplot(1,2,1)
# plt.plot(train_loss, label="Training loss")
# plt.plot(val_loss, label="Validation loss")
# plt.title("MSE losses: Training vs Validation")
# plt.xlabel("Epoch")
# plt.ylabel("Losses")
# plt.legend()

# # Validation
# plt.subplot(1,2,2)
# plt.plot(val_true_rul[:600], label="Actual RUL")
# plt.plot(val_preds[:600], label="Predicted RUL")
# plt.title("Validation Set: Predicted vs Actual RUL")
# plt.xlabel("Sample")
# plt.ylabel("RUL")
# plt.legend()

# plt.tight_layout()
# plt.show()

# %%
# Load parameters
state_dict = torch.load("model/model.pth", map_location=torch.device("cpu"))
model.load_state_dict(state_dict)
model.eval()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[118], line 3
#       1 # Load parameters
#       2 state_dict = torch.load("model/model.pth", map_location=torch.device("cpu"))
# ----> 3 model.load_state_dict(state_dict)
#       4 model.eval()
#
# File ~\miniconda3\Lib\site-packages\torch\nn\modules\module.py:2624, in Module.load_state_dict(self, state_dict, strict, assign)
#    2616         error_msgs.insert(
#    2617             0,
#    2618             "Missing key(s) in state_dict: {}. ".format(
#    2619                 ", ".join(f'"{k}"' for k in missing_keys)
#    2620             ),
#    2621         )
#    2623 if len(error_msgs) > 0:
# -> 2624     raise RuntimeError(
#    2625         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2626             self.__class__.__name__, "\n\t".join(error_msgs)
#    2627         )
#    2628     )
#    2629 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for InformerRUL:
# 	Missing key(s) in state_dict: "input_proj.weight", "input_proj.bias", "encoder.layers.0.attn.q_linear.weight", "encoder.layers.0.attn.q_linear.bias", "encoder.layers.0.attn.k_linear.weight", "encoder.layers.0.attn.k_linear.bias", "encoder.layers.0.attn.v_linear.weight", "encoder.layers.0.attn.v_linear.bias", "encoder.layers.0.attn.fc_out.weight", "encoder.layers.0.attn.fc_out.bias", "encoder.layers.0.norm1.weight", "encoder.layers.0.norm1.bias", "encoder.layers.0.ff.0.weight", "encoder.layers.0.ff.0.bias", "encoder.layers.0.ff.2.weight", "encoder.layers.0.ff.2.bias", "encoder.layers.0.norm2.weight", "encoder.layers.0.norm2.bias", "encoder.layers.1.attn.q_linear.weight", "encoder.layers.1.attn.q_linear.bias", "encoder.layers.1.attn.k_linear.weight", "encoder.layers.1.attn.k_linear.bias", "encoder.layers.1.attn.v_linear.weight", "encoder.layers.1.attn.v_linear.bias", "encoder.layers.1.attn.fc_out.weight", "encoder.layers.1.attn.fc_out.bias", "encoder.layers.1.norm1.weight", "encoder.layers.1.norm1.bias", "encoder.layers.1.ff.0.weight", "encoder.layers.1.ff.0.bias", "encoder.layers.1.ff.2.weight", "encoder.layers.1.ff.2.bias", "encoder.layers.1.norm2.weight", "encoder.layers.1.norm2.bias", "regressor.2.weight", "regressor.2.bias".
# 	Unexpected key(s) in state_dict: "encoder1.weight_ih_l0", "encoder1.weight_hh_l0", "encoder1.bias_ih_l0", "encoder1.bias_hh_l0", "bn.weight", "bn.bias", "bn.running_mean", "bn.running_var", "bn.num_batches_tracked", "encoder2.weight_ih_l0", "encoder2.weight_hh_l0", "encoder2.bias_ih_l0", "encoder2.bias_hh_l0", "fc.weight", "fc.bias".

# %%
# %% [markdown]
# ## 8. Evaluation on Test Set (if RUL available) or inference
# Preprocess test_df for inference
test_dataset  = PHM08RULDataset(test_df, seq_len=seq_len, unit_ids=test_units)
test_loader  = DataLoader(test_dataset, batch_size=64, shuffle=False)

model.eval()
preds = []
true_rul = []
test_loss = 0

model.to(device)
criterion = nn.MSELoss()
with torch.no_grad():
    for x_test, y_test in test_loader:
        x_test, y_test = x_test.to(device), y_test.to(device)
        output = model(x_test)
        preds.extend(output.cpu().numpy().ravel())
        true_rul.extend(y_test.cpu().numpy().ravel())
        test_loss += criterion(output, y_test).item()
avg_test_loss = test_loss / len(test_loader)

print("="*60)
print(f"Test Set Evaluation:")
print(f"MSE: {avg_test_loss:.4f}")
print("="*60)

# Optional: visualize predicted vs true RUL
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(true_rul[:600], label="True RUL")
plt.plot(preds[:600], label="Predicted RUL")
plt.xlabel("Test Sample")
plt.ylabel("RUL")
plt.title("Predicted vs True RUL on Test Set")
plt.legend()
plt.show()
# Out:
# ============================================================
# Test Set Evaluation:
# MSE: 3866.2378
# ============================================================
